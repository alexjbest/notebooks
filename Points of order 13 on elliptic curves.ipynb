# %% [markdown]
# ## Points of order 13 on elliptic curves

# %% [markdown]
# In their _classic paper_ Mazur and Tate prove that the modular curve $X_1(13)$ has no non-cuspidal rational points.
#
# In this notebook we explore this paper  with the experimentalist mindset.

# %% [markdown]
# ### A model

# %% [markdown]
# To play with $X_1(13)$ we can use both "pure thought" or a specific model.
#
# Nowadays its easy to find models for modular curves on the LMFDB or Drews page, but lets first make one by hand for the fun of it.

# %% [markdown]
# First we work out (either from the dimension of the cuspidal subspace or Riemann-Roch) that the curve is of genus 2.
#
# So it is hyperelliptic and there is a model of the form
# $$y^2 = f(x)$$
#
# for  $f(x)$ sextic.
#
# Then the holomorphic 1-forms on such a curve are given by $\mathrm d x / y$ and $x\mathrm d x / y$.
#
# The modular forms are another representation of the holomorphic 1-forms, so we can use this to find $x$ and $y$ in terms of $q$ and then write down an equation relating them.

# %%
M = CuspForms(group=Gamma1(13),weight=2,prec=100); M
# Out:
# Cuspidal subspace of dimension 2 of Modular Forms space of dimension 13 for Congruence Subgroup Gamma1(13) of weight 2 over Rational Field

# %%
M.basis()
# Out:
# [
# q - 4*q^3 - q^4 + 3*q^5 + 6*q^6 - 3*q^8 + q^9 - 6*q^10 - 2*q^12 + 2*q^13 + 10*q^16 - 3*q^17 - 3*q^18 - 6*q^19 + 3*q^20 + 12*q^23 + 2*q^25 - 9*q^26 - 4*q^27 - 6*q^29 + 6*q^30 - 6*q^31 - 9*q^32 + 9*q^34 + 2*q^36 + 6*q^38 + 10*q^39 + 3*q^40 + 8*q^43 - 3*q^45 - 18*q^46 + 6*q^47 - 10*q^48 - 14*q^49 - 6*q^51 + 7*q^52 - 3*q^53 + 12*q^57 + 9*q^58 + 12*q^59 - 6*q^60 + q^61 + 12*q^62 - q^64 - 12*q^65 - 6*q^68 - 12*q^69 + 6*q^71 + 3*q^72 - 3*q^73 + 15*q^74 - 8*q^75 - 6*q^78 + 4*q^79 + 22*q^81 - 9*q^82 - 24*q^83 + 9*q^85 - 24*q^86 + 6*q^87 + 3*q^90 + 6*q^92 - 12*q^94 - 6*q^95 + 18*q^96 + 12*q^97 + 21*q^98 + O(q^100),
# q^2 - 2*q^3 - q^4 + 2*q^5 + 2*q^6 - 2*q^8 + q^9 - 3*q^10 + 3*q^13 - 2*q^15 + 5*q^16 - 3*q^17 - 2*q^18 - 2*q^19 + q^20 + 6*q^23 + 2*q^24 - 7*q^26 - 3*q^29 + 6*q^30 - 4*q^31 - 3*q^32 + 6*q^34 + q^36 - 5*q^37 + 2*q^39 + 3*q^41 + 8*q^43 - q^45 - 6*q^46 + 4*q^47 - 10*q^48 - 7*q^49 + 2*q^50 + 4*q^52 - 4*q^54 + 8*q^57 + 3*q^58 + 4*q^59 - 4*q^60 + q^61 + 6*q^62 - 5*q^65 - 2*q^67 - 3*q^68 - 12*q^69 + 2*q^71 + q^72 - 2*q^73 + 15*q^74 - 4*q^75 + 2*q^76 + 4*q^78 + 5*q^80 + 11*q^81 - 9*q^82 - 16*q^83 + 3*q^85 - 16*q^86 + 6*q^87 + 4*q^89 + 4*q^93 - 6*q^94 - 6*q^95 + 12*q^96 + 4*q^97 + 7*q^98 + O(q^100)
# ]

# %%
f,g = M.basis()
f,g = f.q_expansion(), g.q_expansion()
x = g/f; x
# Out:
# q - 2*q^2 + 3*q^3 - 5*q^4 + 9*q^5 - 17*q^6 + 32*q^7 - 58*q^8 + 104*q^9 - 186*q^10 + 334*q^11 - 603*q^12 + 1090*q^13 - 1969*q^14 + 3552*q^15 - 6404*q^16 + 11546*q^17 - 20822*q^18 + 37559*q^19 - 67752*q^20 + 122211*q^21 - 220431*q^22 + 397579*q^23 - 717094*q^24 + 1293406*q^25 - 2332910*q^26 + 4207864*q^27 - 7589692*q^28 + 13689430*q^29 - 24691422*q^30 + 44535569*q^31 - 80328237*q^32 + 144887077*q^33 - 261331089*q^34 + 471359685*q^35 - 850185574*q^36 + 1533469034*q^37 - 2765898895*q^38 + 4988817393*q^39 - 8998267974*q^40 + 16230064174*q^41 - 29273964892*q^42 + 52801086044*q^43 - 95236661447*q^44 + 171777180699*q^45 - 309832363041*q^46 + 558840777756*q^47 - 1007974156617*q^48 + 1818070442199*q^49 - 3279231030008*q^50 + 5914708197326*q^51 - 10668285565349*q^52 + 19242253906221*q^53 - 34707013899734*q^54 + 62600609039367*q^55 - 112911939451982*q^56 + 203657859983835*q^57 - 367335147500745*q^58 + 662557834010567*q^59 - 1195047319586442*q^60 + 2155491977821154*q^61 - 3887834055018754*q^62 + 7012437900429790*q^63 - 12648246970283726*q^64 + 22813485651188064*q^65 - 41148400152202167*q^66 + 74218857257260454*q^67 - 133867629171458680*q^68 + 241455376736255173*q^69 - 435510058075141584*q^70 + 785524071769943666*q^71 - 1416839992300642288*q^72 + 2555536661351902679*q^73 - 4609389672089316637*q^74 + 8313898787084545512*q^75 - 14995675774696423180*q^76 + 27047513771655179507*q^77 - 48785263980054679085*q^78 + 87993373501773685511*q^79 - 158712552695999064288*q^80 + 286267856099102058915*q^81 - 516337769404688283537*q^82 + 931312008783529184118*q^83 - 1679795879941950390927*q^84 + 3029826923369803162773*q^85 - 5464861115086054641697*q^86 + 9856901982362668495543*q^87 - 17778771435141066659622*q^88 + 32067348778406278454680*q^89 - 57839477909222325719712*q^90 + 104324346484925759986826*q^91 - 188168525424595686623363*q^92 + 339397227526202320006068*q^93 - 612166555445707336300620*q^94 + 1104157197563821567804344*q^95 - 1991554595863770438762639*q^96 + 3592142239399612161682643*q^97 - 6479102252520676478190840*q^98 + O(q^99)

# %% [markdown]
# $$(\frac{y}{dx}) \cdot  dx = \frac{dx}{f/q}$$

# %%
q = x.parent().gen()

# %%
y = x.derivative() / (f/q); y
# Out:
# 1 - 4*q + 13*q^2 - 35*q^3 + 90*q^4 - 223*q^5 + 534*q^6 - 1236*q^7 + 2776*q^8 - 6092*q^9 + 13136*q^10 - 27939*q^11 + 58731*q^12 - 122167*q^13 + 251733*q^14 - 514392*q^15 + 1043437*q^16 - 2102985*q^17 + 4214118*q^18 - 8400786*q^19 + 16667842*q^20 - 32927955*q^21 + 64794320*q^22 - 127039569*q^23 + 248254380*q^24 - 483638931*q^25 + 939528161*q^26 - 1820329007*q^27 + 3518196483*q^28 - 6784086603*q^29 + 13053531004*q^30 - 25066181928*q^31 + 48042417870*q^32 - 91914974442*q^33 + 175556363679*q^34 - 334777507656*q^35 + 637444818342*q^36 - 1212020209560*q^37 + 2301387526809*q^38 - 4364269797737*q^39 + 8266135981096*q^40 - 15638239531011*q^41 + 29552282153769*q^42 - 55787118108008*q^43 + 105205150741311*q^44 - 198207168955914*q^45 + 373077348914286*q^46 - 701604469025582*q^47 + 1318303789942574*q^48 - 2475045280599046*q^49 + 4643112713531777*q^50 - 8703759190252131*q^51 + 16303785765925368*q^52 - 30518677453669137*q^53 + 57088637746147377*q^54 - 106721235752687134*q^55 + 199378869082304118*q^56 - 372257913161510355*q^57 + 694631074486177746*q^58 - 1295443337186190518*q^59 + 2414596956614574492*q^60 - 4498218711863392787*q^61 + 8375553004474276926*q^62 - 15587281905657976938*q^63 + 28994652781875455198*q^64 - 53909140189599655769*q^65 + 100186667566158871243*q^66 - 186108532930044111807*q^67 + 345570778841432433273*q^68 - 641397725527227456786*q^69 + 1189987990690777846056*q^70 - 2206923965408618624344*q^71 + 4091348386869921497988*q^72 - 7582009656792880236222*q^73 + 14045761358547615402588*q^74 - 26010784449480591160167*q^75 + 48151830118686260825841*q^76 - 89110144359237917621274*q^77 + 164854258530456326145366*q^78 - 304884539868428952619334*q^79 + 563684701712302771803200*q^80 - 1041851897407590034711634*q^81 + 1925075557187075044884368*q^82 - 3556023929846413845386842*q^83 + 6566888051559845995252884*q^84 - 12123706985788024304254098*q^85 + 22376639805911794132321805*q^86 - 41289590756277134688110304*q^87 + 76168448708330877029968264*q^88 - 140475614303634178317483161*q^89 + 259012340979169463273710720*q^90 - 477458879687372470090594146*q^91 + 879933254126756777226409599*q^92 - 1621301900529021778977464139*q^93 + 2986624036853530544192241422*q^94 - 5500494769487324585542949232*q^95 + 10128134531510245269778208229*q^96 - 18645137118232969959732404802*q^97 + O(q^98)

# %%
y^2, x,x^2,x^3
# Out:
# (1 - 8*q + 42*q^2 - 174*q^3 + 629*q^4 - 2076*q^5 + 6417*q^6 - 18842*q^7 + 53034*q^8 - 144048*q^9 + 379553*q^10 - 974322*q^11 + 2445042*q^12 - 6014820*q^13 + 14537514*q^14 - 34586364*q^15 + 81125980*q^16 - 187866882*q^17 + 430020792*q^18 - 973919934*q^19 + 2184440934*q^20 - 4856035272*q^21 + 10706544379*q^22 - 23426673318*q^23 + 50898475257*q^24 - 109861605152*q^25 + 235682158209*q^26 - 502713868728*q^27 + 1066561251517*q^28 - 2251461321498*q^29 + 4730283999798*q^30 - 9894025364276*q^31 + 20607767777631*q^32 - 42752464659354*q^33 + 88360021205161*q^34 - 181970064245640*q^35 + 373484147364714*q^36 - 764091366075986*q^37 + 1558428464278170*q^38 - 3169273526339622*q^39 + 6427207745135976*q^40 - 12999578631696234*q^41 + 26225966664557193*q^42 - 52780890467999786*q^43 + 105976501522661094*q^44 - 212310767298565164*q^45 + 424427403149301839*q^46 - 846721931659529760*q^47 + 1685850585500613690*q^48 - 3350202994928614800*q^49 + 6645504827109138813*q^50 - 13158881663244131088*q^51 + 26011888306970461133*q^52 - 51334926843357004584*q^53 + 101150278235427626991*q^54 - 199002212043579019112*q^55 + 390937959153924476103*q^56 - 766899063525458796600*q^57 + 1502343606341049359705*q^58 - 2939140411789657427646*q^59 + 5742615947353481706624*q^60 - 11206115987381892451586*q^61 + 21841028005254240927264*q^62 - 42518665313855476196820*q^63 + 82678008604956196577466*q^64 - 160590115369825393679376*q^65 + 311587467080702721926760*q^66 - 603930376147116162617474*q^67 + 1169370899237544976298667*q^68 - 2261978460096288293176854*q^69 + 4371265466446603512490642*q^70 - 8439558265914451959034290*q^71 + 16279343978715142169792082*q^72 - 31373945684157818300844704*q^73 + 60412448727154131840120012*q^74 - 116230047607556161105194918*q^75 + 223436604307497669945354105*q^76 - 429183549786096053532371832*q^77 + 823745829356583125114722491*q^78 - 1579839874925243303141490636*q^79 + 3027684107857888439667373884*q^80 - 5798202536057028967288893486*q^81 + 11096063763053663024076581581*q^82 - 21219952198457646943360637208*q^83 + 40553343022529129017752341811*q^84 - 77450173564358050582667575372*q^85 + 147821651802654830462251164804*q^86 - 281955038820429222510350646822*q^87 + 537469532607463529007786840961*q^88 - 1023919590619194183814969469298*q^89 + 1949492230023857650330246592514*q^90 - 3709593156915792907841116425482*q^91 + 7054812279385713548737353142602*q^92 - 13409240336832441649393769040444*q^93 + 25473427624808322424355636458084*q^94 - 48365970969080736455286992103516*q^95 + 91783880975351382892665499620618*q^96 - 174089041581561345510094184559090*q^97 + O(q^98),
#  q - 2*q^2 + 3*q^3 - 5*q^4 + 9*q^5 - 17*q^6 + 32*q^7 - 58*q^8 + 104*q^9 - 186*q^10 + 334*q^11 - 603*q^12 + 1090*q^13 - 1969*q^14 + 3552*q^15 - 6404*q^16 + 11546*q^17 - 20822*q^18 + 37559*q^19 - 67752*q^20 + 122211*q^21 - 220431*q^22 + 397579*q^23 - 717094*q^24 + 1293406*q^25 - 2332910*q^26 + 4207864*q^27 - 7589692*q^28 + 13689430*q^29 - 24691422*q^30 + 44535569*q^31 - 80328237*q^32 + 144887077*q^33 - 261331089*q^34 + 471359685*q^35 - 850185574*q^36 + 1533469034*q^37 - 2765898895*q^38 + 4988817393*q^39 - 8998267974*q^40 + 16230064174*q^41 - 29273964892*q^42 + 52801086044*q^43 - 95236661447*q^44 + 171777180699*q^45 - 309832363041*q^46 + 558840777756*q^47 - 1007974156617*q^48 + 1818070442199*q^49 - 3279231030008*q^50 + 5914708197326*q^51 - 10668285565349*q^52 + 19242253906221*q^53 - 34707013899734*q^54 + 62600609039367*q^55 - 112911939451982*q^56 + 203657859983835*q^57 - 367335147500745*q^58 + 662557834010567*q^59 - 1195047319586442*q^60 + 2155491977821154*q^61 - 3887834055018754*q^62 + 7012437900429790*q^63 - 12648246970283726*q^64 + 22813485651188064*q^65 - 41148400152202167*q^66 + 74218857257260454*q^67 - 133867629171458680*q^68 + 241455376736255173*q^69 - 435510058075141584*q^70 + 785524071769943666*q^71 - 1416839992300642288*q^72 + 2555536661351902679*q^73 - 4609389672089316637*q^74 + 8313898787084545512*q^75 - 14995675774696423180*q^76 + 27047513771655179507*q^77 - 48785263980054679085*q^78 + 87993373501773685511*q^79 - 158712552695999064288*q^80 + 286267856099102058915*q^81 - 516337769404688283537*q^82 + 931312008783529184118*q^83 - 1679795879941950390927*q^84 + 3029826923369803162773*q^85 - 5464861115086054641697*q^86 + 9856901982362668495543*q^87 - 17778771435141066659622*q^88 + 32067348778406278454680*q^89 - 57839477909222325719712*q^90 + 104324346484925759986826*q^91 - 188168525424595686623363*q^92 + 339397227526202320006068*q^93 - 612166555445707336300620*q^94 + 1104157197563821567804344*q^95 - 1991554595863770438762639*q^96 + 3592142239399612161682643*q^97 - 6479102252520676478190840*q^98 + O(q^99),
#  q^2 - 4*q^3 + 10*q^4 - 22*q^5 + 47*q^6 - 100*q^7 + 211*q^8 - 436*q^9 + 883*q^10 - 1762*q^11 + 3481*q^12 - 6830*q^13 + 13324*q^14 - 25852*q^15 + 49906*q^16 - 95908*q^17 + 183600*q^18 - 350298*q^19 + 666380*q^20 - 1264300*q^21 + 2392892*q^22 - 4518892*q^23 + 8516499*q^24 - 16020894*q^25 + 30086772*q^26 - 56413794*q^27 + 105624885*q^28 - 197498230*q^29 + 368821780*q^30 - 687959474*q^31 + 1281843986*q^32 - 2385961422*q^33 + 4436849618*q^34 - 8243159706*q^35 + 15301815914*q^36 - 28382010066*q^37 + 52603329549*q^38 - 97425066096*q^39 + 180314936724*q^40 - 333511740326*q^41 + 616485388635*q^42 - 1138884037756*q^43 + 2102776920573*q^44 - 3880386442366*q^45 + 7157068872823*q^46 - 13194214378592*q^47 + 24312468574142*q^48 - 44779604188938*q^49 + 82441347965912*q^50 - 151715882077262*q^51 + 279090583118524*q^52 - 513208843630758*q^53 + 943374541610950*q^54 - 1733489259804226*q^55 + 3184276182554478*q^56 - 5847337457266092*q^57 + 10734169574781424*q^58 - 19699098713996890*q^59 + 36140684777564594*q^60 - 66286149586069396*q^61 + 121542921285432967*q^62 - 222802921258801760*q^63 + 408319488524749147*q^64 - 748119312369183596*q^65 + 1370365769516494235*q^66 - 2509575191496141426*q^67 + 4594783477992120721*q^68 - 8410734700960899054*q^69 + 15392517407745100715*q^70 - 28164035207597534520*q^71 + 51521935179140319182*q^72 - 94233206391303871214*q^73 + 172318788801415033384*q^74 - 315050675137135587946*q^75 + 575903178918682758313*q^76 - 1052547961783739052528*q^77 + 1923355959823677404041*q^78 - 3514023925742717287054*q^79 + 6419170050723704158638*q^80 - 11724219601104591041908*q^81 + 21410243967124887140888*q^82 - 39092508915121798390852*q^83 + 71367636828539215527992*q^84 - 130270615491050598594674*q^85 + 237755442590688536834736*q^86 - 433865132034827774946138*q^87 + 791627160814953553445087*q^88 - 1444207543270623322516134*q^89 + 2634406572326812061880805*q^90 - 4804868478913996717026352*q^91 + 8762477571621265597884737*q^92 - 15977918704772665506951028*q^93 + 29131476135655678303735148*q^94 - 53107378022616390491819016*q^95 + 96805128711126058644056507*q^96 - 176438773923393538773876954*q^97 + 321545800852448589894694241*q^98 - 585930032323396228228418588*q^99 + O(q^100),
#  q^3 - 6*q^4 + 21*q^5 - 59*q^6 + 150*q^7 - 363*q^8 + 852*q^9 - 1947*q^10 + 4341*q^11 - 9476*q^12 + 20331*q^13 - 43017*q^14 + 89970*q^15 - 186303*q^16 + 382395*q^17 - 778754*q^18 + 1574940*q^19 - 3165462*q^20 + 6327077*q^21 - 12583434*q^22 + 24912963*q^23 - 49119547*q^24 + 96480075*q^25 - 188846661*q^26 + 368458157*q^27 - 716769492*q^28 + 1390518951*q^29 - 2690692068*q^30 + 5194166874*q^31 - 10004615724*q^32 + 19229984578*q^33 - 36889877925*q^34 + 70637612664*q^35 - 135024213492*q^36 + 257677540692*q^37 - 490986647388*q^38 + 934171958275*q^39 - 1774929227892*q^40 + 3367928444811*q^41 - 6382642820740*q^42 + 12081485172252*q^43 - 22842655149270*q^44 + 43142172594348*q^45 - 81396883558347*q^46 + 153420590846724*q^47 - 288900390283514*q^48 + 543523765168170*q^49 - 1021671163227939*q^50 + 1918850731485833*q^51 - 3600999584568282*q^52 + 6752588741425317*q^53 - 12653061917309279*q^54 + 23692511978298912*q^55 - 44333100281439240*q^56 + 82900543428586085*q^57 - 154920582435736278*q^58 + 289329683557484676*q^59 - 540030331048653768*q^60 + 1007379952724216091*q^61 - 1878134603270795373*q^62 + 3499663188649049934*q^63 - 6517775493964410183*q^64 + 12132583563943541319*q^65 - 22573283402645138694*q^66 + 41978818976315839725*q^67 - 78030777586783691388*q^68 + 144979905437930213086*q^69 - 269253595198150333647*q^70 + 499841658771122927514*q^71 - 927525405873097629478*q^72 + 1720467907495388023470*q^73 - 3190064751636674818818*q^74 + 5912745020731844748979*q^75 - 10955190130388405977650*q^76 + 20290652550511106167422*q^77 - 37568294686659965602265*q^78 + 69534480027770784481746*q^79 - 128657747421279950172828*q^80 + 237975515996371033972918*q^81 - 440040528822088998642294*q^82 + 813430557594997891174404*q^83 - 1503207414391063753133572*q^84 + 2777097045594624060016566*q^85 - 5129085224441623914390309*q^86 + 9470401062840123329146768*q^87 - 17481520745138742973272951*q^88 + 32260799107229540979393999*q^89 - 59519421650815340808588435*q^90 + 109782335749543461631359360*q^91 - 202441171281906584046195396*q^92 + 373215932308975697730806993*q^93 - 687889595041749591864950712*q^94 + 1267583964229409184929827152*q^95 - 2335265658751141209504111264*q^96 + 4301297406984324692942969994*q^97 - 7920785876599770538255782255*q^98 + 14582924670522825679104653338*q^99 - 26842961473394049962681797284*q^100 + O(q^101))

# %%
L = []
L.append([(y^2)[n] for n in range(98)])
for i in range(7):
    L.append([(x^i)[n] for n in range(98)])

# %%
matrix(L).kernel().basis()
# Out:
# [
# (1, -1, 8, -26, 46, -53, 42, -17)
# ]

# %% [markdown]
# So our model is:
# $$y^2 = 17x^6 - 42x^5 + 53x^4-46x^3+26x^2 -8x  + 1$$

# %%
X = polygen(QQ)
X13 = HyperellipticCurve(17*X^6 - 42*X^5 + 53*X^4-46*X^3+26*X^2 -8*X  + 1); X13
# Out:
# Hyperelliptic Curve over Rational Field defined by y^2 = 17*x^6 - 42*x^5 + 53*x^4 - 46*x^3 + 26*x^2 - 8*x + 1

# %% [markdown]
# To look a genus 2 curve up one can compute its Igusa-Clebsch invariants
# $$I_2,I_4,I_6,I_{10} $$

# %%
I2,I4,I6,I10 = X13.igusa_clebsch_invariants()
I2,I4,I6,I10
# Out:
# (128, 812032, 123109376, -725849473024)

# %% [markdown]
# https://www.lmfdb.org/Genus2Curve/Q/?geometric_invariants=[128,812032,123109376,-725849473024]
#
#
# For genus 2 curves over $\mathbf Q$ we may assume that the Igusa-Clebsch invariants are integral. We can then normalize them by removing a factor of $d^k$ from $I_{2k}$, where $d$ is the largest positive integer for which the invariants remain integral after this normalization.

# %%
[i.factor() for i in X13.igusa_clebsch_invariants()]
# Out:
# [2^7, 2^10 * 13 * 61, 2^15 * 13 * 17^2, -1 * 2^32 * 13^2]

# %%
I2/(2^5), I4/(2^(2*5)), I6/(2^(3*5)), I10/(2^(5*5))
# Out:
# (4, 793, 3757, -21632)

# %% [markdown]
# https://www.lmfdb.org/Genus2Curve/Q/?geometric_invariants=[4,793,3757,-21632]

# %% [markdown]
# I think this is a bug in the lmfdb....

# %%
I2/(2^4), I4/(2^(2*4)), I6/(2^(3*4)), I10/(2^(5*4))
# Out:
# (8, 3172, 30056, -692224)

# %% [markdown]
# https://www.lmfdb.org/Genus2Curve/Q/?geometric_invariants=[8,3172,30056,-692224]

# %% [markdown]
# The one from lmfdb is as follows
# $$y^2 + (x^3 + x + 1)y = x^5 + x^4$$

# %% [markdown]
# ### Curves with 19-torsion
#
# Mazur-Tate say
# > It seemed (to us and
# to Swinnerton-Dyer) that if such an abelian variety J, which has bad
# reduction at only one prime, and has a sizeable number of endomorphisms,
# has a point of order 19, it is not entitled to have any other points.
#
# So lets experiment and see how rare this really is.
#
# It seems there are (several different) families of genus 2 curves with a 19-torsion point in their Jacobian, I'll give one from
# >Leprévost, Franck. “Torsion sur des familles de courbes de genre g.” manuscripta mathematica 75, no. 1 (December 1, 1992): 303–26. https://doi.org/10.1007/BF02567087.
#
# In "Prolegomena to a Middlebrow Arithmetic of Curves of Genus 2 curves" by Cassels & Flynn they give the following explaination of how to do this.
#
# If we want to find an elliptic curve with 5-torsion we can set
# $$\mathcal{E}_{A, \lambda}: \quad Y^{2}=(A(X))^{2}-\lambda X(X-1)^{2}$$
#
# with $A(X)$ linear in $X$ over $\mathbf Q(t)$ and $\lambda \in \mathbf Q(t)$.
#
# This form of equation forces us to have at least 2 rational points
# $$P_{0}=(0, A(0)), \quad P_{1}=(1, A(1))$$
# and a divisor $Y - A(x)$ gives us that in the jacobian
# $$1 \cdot P_{0}+2 \cdot P_{1} = 0.$$
#
# If we also knew that
# $$3 \cdot P_{0}+1 \cdot P_{1} = 0$$
# we would be able to pin down the group they generate via
# $$M \cdot\left(\begin{array}{c}
# P_{0} \\
# P_{1}
# \end{array}\right)=\left(\begin{array}{l}
# 0 \\
# 0
# \end{array}\right), M=\left(\begin{array}{ll}
# 1 & 2 \\
# 3 & 1
# \end{array}\right)
# $$
# $$5 \cdot\left(\begin{array}{c}
# P_{0} \\
# P_{1}
# \end{array}\right)=-\operatorname{det}(M) \cdot\left(\begin{array}{c}
# P_{0} \\
# P_{1}
# \end{array}\right)=\left(\begin{array}{c}
# 0 \\
# 0
# \end{array}\right)$$
# So we now have an algebraic condition (the existence of some function / divisor, when we vary $A$ and $\lambda$) to give us 5-torsion.
#
# In the case of 5-torsion on an elliptic curve we end up with
# $$A=\frac{1}{2}\left(X^{2}-t(X-1)-X(X-1)\right)=\frac{1}{2}((1-t) X+t), \quad \lambda=t$$

# %%
P.<t> = FunctionField(Rationals()); P
# Out:
# Rational function field in t over Rational Field

# %%
a2=-(t^10+6*t^9+29*t^8+168*t^7+482*t^6-348*t^5+482*t^4+168*t^3+29*t^2+6*t+1);a2
# Out:
# -t^10 - 6*t^9 - 29*t^8 - 168*t^7 - 482*t^6 + 348*t^5 - 482*t^4 - 168*t^3 - 29*t^2 - 6*t - 1

# %%
a1=2*(t+1)^2*(t^8+4*t^7+20*t^6+92*t^5+22*t^4+92*t^3+20*t^2+4*t+1); a1
# Out:
# 2*t^10 + 12*t^9 + 58*t^8 + 272*t^7 + 452*t^6 + 456*t^5 + 452*t^4 + 272*t^3 + 58*t^2 + 12*t + 2

# %%
a0=-(t+1)^6*(t^4+14*t^2+1);a0
# Out:
# -t^10 - 6*t^9 - 29*t^8 - 104*t^7 - 226*t^6 - 292*t^5 - 226*t^4 - 104*t^3 - 29*t^2 - 6*t - 1

# %%
λ=1024*t^4*(t^2-1)^2*(t^4+14*t^2+1)^2;λ
# Out:
# 1024*t^16 + 26624*t^14 + 146432*t^12 - 348160*t^10 + 146432*t^8 + 26624*t^6 + 1024*t^4

# %%
x = polygen(P)
H = HyperellipticCurve((a2*x^2 + a1*x + a0)^2 - λ*x^3*(x-1)^2);H
# Out:
# Hyperelliptic Curve over Rational function field in t over Rational Field defined by y^2 = (-1024*t^16 - 26624*t^14 - 146432*t^12 + 348160*t^10 - 146432*t^8 - 26624*t^6 - 1024*t^4)*x^5 + (t^20 + 12*t^19 + 94*t^18 + 684*t^17 + 5869*t^16 + 14832*t^15 + 106216*t^14 + 147888*t^13 + 438290*t^12 - 163416*t^11 - 52364*t^10 - 163416*t^9 + 438290*t^8 + 147888*t^7 + 106216*t^6 + 14832*t^5 + 5869*t^4 + 684*t^3 + 94*t^2 + 12*t + 1)*x^4 + (-4*t^20 - 48*t^19 - 376*t^18 - 2608*t^17 - 14516*t^16 - 51776*t^15 - 200096*t^14 - 418368*t^13 - 635720*t^12 - 575776*t^11 - 395728*t^10 - 575776*t^9 - 635720*t^8 - 418368*t^7 - 200096*t^6 - 51776*t^5 - 14516*t^4 - 2608*t^3 - 376*t^2 - 48*t - 4)*x^3 + (6*t^20 + 72*t^19 + 564*t^18 + 3720*t^17 + 18062*t^16 + 68384*t^15 + 215920*t^14 + 492704*t^13 + 799596*t^12 + 1007984*t^11 + 1077432*t^10 + 1007984*t^9 + 799596*t^8 + 492704*t^7 + 215920*t^6 + 68384*t^5 + 18062*t^4 + 3720*t^3 + 564*t^2 + 72*t + 6)*x^2 + (-4*t^20 - 48*t^19 - 376*t^18 - 2352*t^17 - 10932*t^16 - 40768*t^15 - 123296*t^14 - 289088*t^13 - 516424*t^12 - 716320*t^11 - 795088*t^10 - 716320*t^9 - 516424*t^8 - 289088*t^7 - 123296*t^6 - 40768*t^5 - 10932*t^4 - 2352*t^3 - 376*t^2 - 48*t - 4)*x + t^20 + 12*t^19 + 94*t^18 + 556*t^17 + 2541*t^16 + 9328*t^15 + 27880*t^14 + 66864*t^13 + 126226*t^12 + 185384*t^11 + 210804*t^10 + 185384*t^9 + 126226*t^8 + 66864*t^7 + 27880*t^6 + 9328*t^5 + 2541*t^4 + 556*t^3 + 94*t^2 + 12*t + 1

# %% [markdown]
# To specialise this family to different $t$ we can just plug different $t$ in to the above long expression.
# We can phrase this in a mathematically fancy way though, we have a curve over a base and the places of the base correspond to different $t$, so passing to the fibre over a place gives us the fibres of the family.

# %%
O = P.maximal_order()
i = O.ideal(t+1/2)
qq12,f12,g12 = i.place().residue_field()

# %%
H12 = H.base_extend(g12); H12
# Out:
# Hyperelliptic Curve over Rational Field defined by y^2 = -47961/64*x^5 + 2616750289/1048576*x^4 - 124322257/262144*x^3 + 12314739/524288*x^2 + 162863/262144*x + 5329/1048576

# %% [markdown]
# How can we check for 19-torsion? Torsion injects into the reduction mod $p$ for primes of good reduction, so if we check a few different $p$ we should be convinced.

# %%
Hp = H12.change_ring(GF(next_prime(261))); Hp
# Out:
# Hyperelliptic Curve over Finite Field of size 263 defined by y^2 = 167*x^5 + 112*x^4 + 95*x^3 + 147*x^2 + 105*x + 144

# %%
Hp.frobenius_polynomial()(1).factor()
# Out:
# 19 * 3607

# %% [markdown]
# ## Experiments / exploration questions:
#
# - Play with this family for various $t$, what if we use a place of higher degree?
# - Do any of these curves have more torsion? One can rule out 38 torsion by looking at small places, using the Riemann hypothesis for zeta functions (torsion injects!)
# - What sort of bad reduction do these curves generally have, roughly this is the discriminant of $f$ times the leading coefficient of $f$ (as if $p$ divides that coeff the reduction wouldn't be genus 2), and the discriminant is the last Igusa-Clebsch.
# - Does any value of $t$ give you our curve from before? (maybe they all have bad reduction somewhere? I've no idea)
# - See if any of them have larger rank (maybe use Magma)
# - See if any of them have endomorphisms (maybe use Magma `AnalyticEndomorphisms`)
#
# Notes: don't bother with the lmfdb, there is only 1 curve with 19-torsion in the lmfdb, our friend $X_1(13)$.
# Magma online calculator is fine for this http://magma.maths.usyd.edu.au/calc/

# %%
H12.igusa_clebsch_invariants()[-1].factor()
# Out:
# 2^-57 * 3^30 * 73^11 * 3389 * 42737

# %%
i = O.ideal(t+3)
qq3,f3,g3 = i.place().residue_field()
H3 = H.base_extend(g3)
[i.factor() for i in H3.igusa_clebsch_invariants()]
# Out:
# [2^52 * 3^4 * 17 * 47 * 4793,
#  2^100 * 3^8 * 7 * 63299 * 84595853,
#  2^150 * 3^12 * 61 * 173 * 11165025631404703,
#  2^268 * 3^35 * 13^11 * 53773]

# %%
H3
# Out:
# Hyperelliptic Curve over Rational Field defined by y^2 = -229663309824*x^5 + 514314993664*x^4 - 190282989568*x^3 + 13293846528*x^2 + 2235564032*x + 177209344

# %%
for l in range(4,1000):
    i = O.ideal(t-l)
    qq3,f3,g3 = i.place().residue_field()
    H3 = H.base_extend(g3)
    
    L = []
    for p in prime_range(400,470):
        try:
            L.append(H3.change_ring(GF(p)).frobenius_polynomial()(1))
        except ValueError:
            pass
    if gcd(L) > 19:
        print(H3, gcd(L), l)
# Out:
# Hyperelliptic Curve over Rational Field defined by y^2 = -54396565408122849460224*x^5 + 9168509728874416716120064*x^4 - 36070362049942950927925248*x^3 + 53723918470888096769507328*x^2 - 35638401530432804993630208*x + 8870761906671439209037824 76 17
# Hyperelliptic Curve over Rational Field defined by y^2 = -24842374045787750400000000*x^5 + 15381206653133426884451762176*x^4 - 61225976265831326023055048704*x^3 + 91628788966289787911254573056*x^2 - 60980205750235166539151048704*x + 15221032088449065516899762176 38 25
# Hyperelliptic Curve over Rational Field defined by y^2 = -97423268229619694477553844224*x^5 + 393913925696033348781590296142689*x^4 - 1574282593226914663034256193321348*x^3 + 2360294479031022385876102214187078*x^2 - 1572909718181784390445333286277508*x + 393081331742994284907257077854049 38 42
# Hyperelliptic Curve over Rational Field defined by y^2 = -416622531153811938710376038400*x^5 + 2364055428351767369268691014848401*x^4 - 9450144714553426665279319939867204*x^3 + 14170077905588426324867012517276006*x^2 - 9443860117357452172297610409192004*x + 2360288125889405398028803845133201 38 46
# Hyperelliptic Curve over Rational Field defined by y^2 = -1930488747604575695152275769933824*x^5 + 81360314746940975325535854625604022289*x^4 - 325405445211635298501400480275040609348*x^3 + 488072836584998166546235541435232562278*x^2 - 325360943940212046126473342731636567108*x + 81335168311812262699915915303797650449 38 78
# Hyperelliptic Curve over Rational Field defined by y^2 = -27054411644842700692356631447732224*x^5 + 2155827693591987443707211389134927536689*x^4 - 8622761733530832328932545735941076068548*x^3 + 12933576646555531932268959273813447159078*x^2 - 8622043593651866551732508447138370087108*x + 2155428041469889063774157744269475955249 38 92
# Hyperelliptic Curve over Rational Field defined by y^2 = -3204652403744579555129389584384000000*x^5 + 814922280363133730600115697837980919969201*x^4 - 3259611303618424550679762702312136918562500*x^3 + 4889330724681228304050595833221017089843750*x^2 - 3259500636641520053070682764053344726562500*x + 814862139868824757286347448825836181640625 38 124
# Hyperelliptic Curve over Rational Field defined by y^2 = -6824352360030291833826516602480640000*x^5 + 2087129163804796214504495906676526231028161*x^4 - 8348345832961404121250871899593114511696644*x^3 + 12522327452612693115790487339809399481400966*x^2 - 8348099939694923326158757839874532588624644*x + 2086995980592678569610721188962797468532161 38 130
# Hyperelliptic Curve over Rational Field defined by y^2 = -9830243711729508755177164793890996224*x^5 + 3286879037768877519880982394642811992408064*x^4 - 13147266408017078455938198151664405806317568*x^3 + 19720618532872064928946818085390267164131328*x^2 - 13146904841410556653068607027083693279674368*x + 3286683509032352388928111953138801200594944 38 133
# Hyperelliptic Curve over Rational Field defined by y^2 = -6197752951532723394051318720013271040000*x^5 + 10080894902467898876926483168265290779722776576*x^4 - 40323371083174893593964119969486354797035520000*x^3 + 60484802775714784528055140054036748697600000000*x^2 - 40323040922985838503656402452480000000000000000*x + 10080720525731247947776000000000000000000000000 38 199
# Hyperelliptic Curve over Rational Field defined by y^2 = -62828798632861933567737686890713507840000*x^5 + 180884401654534199939357260998215747642517093361*x^4 - 723535249420640735311646362986323794753291797444*x^3 + 1085299935755005374887224950445874586137503712166*x^2 - 723531415722062810389288717859463712291901205444*x + 180882390561964015118201118353741803908280037361 38 230
# Hyperelliptic Curve over Rational Field defined by y^2 = -8692097836443976884057201776260432709812224*x^5 + 84651855480222870623333625372126564762956531236864*x^4 - 338607005672852431319492082637652263707258061324288*x^3 + 507909966767710024903955795604249096191224345264128*x^2 - 338606294977255817019445440374176433745731547824128*x + 84651487094273246463129965618486047458901611249664 38 313
# Hyperelliptic Curve over Rational Field defined by y^2 = -34234746856407911603475215956862914107801600*x^5 + 468224712510414285305467615218372069335292603006976*x^4 - 1872897090819724613447718052745833946004790972514304*x^3 + 2809343322827634301524368790622684722852071794016256*x^2 - 1872894052063989521560493529963688226597256774549504*x + 468223141780412564700774702623544343411250798002176 38 341
# Hyperelliptic Curve over Rational Field defined by y^2 = -652993462644501299140717234481939275376640000*x^5 + 18554356026826584035434890701011311808111296730060321*x^4 - 74217384921159484774110171412002298626795930789553284*x^3 + 111326024809142845158671009395059431997232904911177926*x^2 - 74217315697145951399578444075020961299461968610737284*x + 18554320435329471088431063762598903551689734735692321 38 410
# Hyperelliptic Curve over Rational Field defined by y^2 = -823869627141935621301307352118496211868057600*x^5 + 24799924962233489398170103540135018678665598710729601*x^4 - 99199649790722309425640727490435603995048047097228804*x^3 + 148799407429489165758589236979680898871651835092256006*x^2 - 99199561216396853758219141008601603098602876463296004*x + 24799879439266136912524148903403625279216329352956801 38 416
# Hyperelliptic Curve over Rational Field defined by y^2 = -2895715803055132057522343465199497990400000000*x^5 + 119091095324631088198529768165961713918243093029790401*x^4 - 476364193050566090189219709095409918006757304455161604*x^3 + 714546034726083951279801794087186539238235623986742406*x^2 - 476363857120413939372566774964817960845281754727161604*x + 119090923015980797617425500997810728655058332565790401 38 450
# Hyperelliptic Curve over Rational Field defined by y^2 = -7606690055344839226695619860716037543217741824*x^5 + 397651913947542192335908086601729240045091633659998289*x^4 - 1590607134666519736321004858323947183431378274283930948*x^3 + 2385909992609693628667237472387140929034875195401506278*x^2 - 1590606198976544284839143189566292687078609160180419908*x + 397651434692518264748325655510245759197034973589460049 38 478
# Hyperelliptic Curve over Rational Field defined by y^2 = -53535126831759054432096166638128152091197440000*x^5 + 4545266191801060388374220302900236103538957669542232881*x^4 - 18181060684743325487989743566489546912838496504183139524*x^3 + 27271585412205621157986398071022274853019392429306901286*x^2 - 18181053269709862248565621388123539179898185518326115524*x + 4545262403981633061946901094449828024830998728457560881 38 540
# Hyperelliptic Curve over Rational Field defined by y^2 = -71802623958825161825315449536289469702400000000*x^5 + 6557846438281930482015994405527791897732798799010191601*x^4 - 26231380187887725329123559211032981087691762918744766404*x^3 + 39347062616357651459907163563185389370141130774973149606*x^2 - 26231370063166715108154532945508977301033219477752766404*x + 6557841268217482504030745892682366000500522524914191601 38 550
# Hyperelliptic Curve over Rational Field defined by y^2 = -104344580471735313410247948206552945610115252224*x^5 + 10458155355294570997949714093646240113296415856985636864*x^4 - 41832613164151447930878958745307436346712456330674700288*x^3 + 62748908352331146807771569155929282868444582386365104128*x^2 - 41832598111663312549215748841238601466322022967046832128*x + 10458147672533623212100898986153231410000356910682865664 38 563
# ---------------------------------------------------------------------
# KeyboardInterrupt                   Traceback (most recent call last)
# <ipython-input-297-6325caab42b2> in <module>
#       7     for p in prime_range(Integer(400),Integer(470)):
#       8         try:
# ----> 9             L.append(H3.change_ring(GF(p)).frobenius_polynomial()(Integer(1)))
#      10         except ValueError:
#      11             pass
#
# ~/sage/local/lib/python3.7/site-packages/sage/schemes/hyperelliptic_curves/hyperelliptic_generic.py in change_ring(self, R)
#     143         y = self._printing_ring.variable_name()
#     144         x = self._printing_ring.base_ring().variable_name()
# --> 145         return HyperellipticCurve(f.change_ring(R), h.change_ring(R), "%s,%s"%(x,y))
#     146
#     147     base_extend = change_ring
#
# ~/sage/local/lib/python3.7/site-packages/sage/rings/polynomial/polynomial_element.pyx in sage.rings.polynomial.polynomial_element.Polynomial.change_ring (build/cythonized/sage/rings/polynomial/polynomial_element.c:31506)()
#    3251             return self.map_coefficients(R)
#    3252         else:
# -> 3253             return self._parent.change_ring(R)(self.list(copy=False))
#    3254
#    3255     cpdef dict _mpoly_dict_recursive(self, tuple variables=None, base_ring=None):
#
# ~/sage/local/lib/python3.7/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:9336)()
#     898         if mor is not None:
#     899             if no_extra_args:
# --> 900                 return mor._call_(x)
#     901             else:
#     902                 return mor._call_with_args(x, args, kwds)
#
# ~/sage/local/lib/python3.7/site-packages/sage/structure/coerce_maps.pyx in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:4515)()
#     154         cdef Parent C = self._codomain
#     155         try:
# --> 156             return C._element_constructor(x)
#     157         except Exception:
#     158             if print_warnings:
#
# ~/sage/local/lib/python3.7/site-packages/sage/rings/polynomial/polynomial_ring.py in _element_constructor_(self, x, check, is_gen, construct, **kwds)
#     417         C = self.element_class
#     418         if isinstance(x, (list, tuple)):
# --> 419             return C(self, x, check=check, is_gen=False, construct=construct)
#     420         if isinstance(x, range):
#     421             return C(self, list(x), check=check, is_gen=False,
#
# ~/sage/local/lib/python3.7/site-packages/sage/rings/polynomial/polynomial_zmod_flint.pyx in sage.rings.polynomial.polynomial_zmod_flint.Polynomial_zmod_flint.__init__ (build/cythonized/sage/rings/polynomial/polynomial_zmod_flint.cpp:13883)()
#     100             k = parent._base
#     101             if check:
# --> 102                 lst = [k(i) for i in x]
#     103             else:
#     104                 lst = x
#
# ~/sage/local/lib/python3.7/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:9336)()
#     898         if mor is not None:
#     899             if no_extra_args:
# --> 900                 return mor._call_(x)
#     901             else:
#     902                 return mor._call_with_args(x, args, kwds)
#
# ~/sage/local/lib/python3.7/site-packages/sage/structure/coerce_maps.pyx in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:4515)()
#     154         cdef Parent C = self._codomain
#     155         try:
# --> 156             return C._element_constructor(x)
#     157         except Exception:
#     158             if print_warnings:
#
# ~/sage/local/lib/python3.7/site-packages/sage/rings/finite_rings/integer_mod_ring.py in _element_constructor_(self, x)
#    1160         """
#    1161         try:
# -> 1162             return integer_mod.IntegerMod(self, x)
#    1163         except (NotImplementedError, PariError):
#    1164             raise TypeError("error coercing to finite field")
#
# ~/sage/local/lib/python3.7/site-packages/sage/rings/finite_rings/integer_mod.pyx in sage.rings.finite_rings.integer_mod.IntegerMod (build/cythonized/sage/rings/finite_rings/integer_mod.c:4726)()
#     197             return a
#     198     t = modulus.element_class()
# --> 199     return t(parent, value)
#     200
#     201
#
# ~/sage/local/lib/python3.7/site-packages/sage/rings/finite_rings/integer_mod.pyx in sage.rings.finite_rings.integer_mod.IntegerMod_abstract.__init__ (build/cythonized/sage/rings/finite_rings/integer_mod.c:5944)()
#     370             z = <Integer>value
#     371         elif isinstance(value, rational.Rational):
# --> 372             z = value % self.__modulus.sageInteger
#     373         elif integer_check_long_py(value, &longval, &err) and not err:
#     374             self.set_from_long(longval)
#
# ~/sage/local/lib/python3.7/site-packages/sage/rings/rational.pyx in sage.rings.rational.Rational.__mod__ (build/cythonized/sage/rings/rational.c:23654)()
#    2804         n = rat.numer() % other
#    2805         d = rat.denom() % other
# -> 2806         d = d.inverse_mod(other)
#    2807         return (n * d) % other
#    2808
#
# ~/sage/local/lib/python3.7/site-packages/sage/rings/integer.pyx in sage.rings.integer.Integer.inverse_mod (build/cythonized/sage/rings/integer.c:41648)()
#    6746         if mpz_cmpabs_ui(m.value, 1) == 0:
#    6747             return zero
# -> 6748         sig_on()
#    6749         r = mpz_invert(ans.value, self.value, m.value)
#    6750         sig_off()
#
# KeyboardInterrupt:

# %%
Hasd = HyperellipticCurve(-54396565408122849460224*x^5 + 9168509728874416716120064*x^4 - 36070362049942950927925248*x^3 + 53723918470888096769507328*x^2 - 35638401530432804993630208*x + 8870761906671439209037824)

# %%
J = Hasd.jacobian()

# %%
J.

# %%
_.factor()
# Out:
# (-54396565408122849460224) * (x^5 - 8743772248148361889/51876607330439424*x^4 + 106170919353411377/160112985587776*x^3 - 316266180385119219/320225971175552*x^2 + 19166722054929/29255067712*x - 3486784401/21381376)

# %%
prime_range(400,470)
# Out:
# [401, 409, 419, 421, 431, 433, 439, 443, 449, 457, 461, 463, 467]

# %% [markdown]
# e.g. some magma code:
# ```
# R<x>:=PolynomialRing(Rationals());
# H:= HyperellipticCurve(-47961/64*x^5 + 2616750289/1048576*x^4 -124322257/262144*x^3 + 12314739/524288*x^2 + 162863/262144*x +5329/1048576);
# RankBounds(Jacobian(H));
# ```

# %%
H.igusa_clebsch_invariants()[-1].factor()
# Out:
# (40564819207303340847894502572032) * (t - 1)^30 * t^35 * (t + 1)^36 * (t^4 + 14*t^2 + 1)^11 * (t^20 + 33/2*t^19 + 163*t^18 + 2873/2*t^17 + 4069*t^16 + 31994*t^15 + 32180*t^14 + 159426*t^13 + 16346*t^12 - 684393*t^11 - 1219630*t^10 - 684393*t^9 + 16346*t^8 + 159426*t^7 + 32180*t^6 + 31994*t^5 + 4069*t^4 + 2873/2*t^3 + 163*t^2 + 33/2*t + 1)

# %%
H.hyperelliptic_polynomials()[0].leading_coefficient().factor()
# Out:
# (-1024) * (t - 1)^2 * t^4 * (t + 1)^2 * (t^4 + 14*t^2 + 1)^2

# %%
Gamma0(13).index()
# Out:
# 14

# %%
168/14
# Out:
# 12

# %%
ModularForms(GammaH(13, [1,4])).basis()
# Out:
# [
# 1 - 8*q^4 + 12*q^5 + O(q^6),
# q + 4*q^3 - q^4 + 6*q^5 + O(q^6),
# q^2 + 4*q^4 - 2*q^5 + O(q^6)
# ]

# %%
t = EtaGroupElement(EtaGroup(13),{1:2,13:-2})

# %%
for w in QQ.range_by_height(10):
    if h(-w).squarefree_part() == 17:
        print(-w,h(-w),h(-w).squarefree_part().factor())
# Out:
# ---------------------------------------------------------------------
# NameError                           Traceback (most recent call last)
# <ipython-input-321-48773626ce52> in <module>
#       1 for w in QQ.range_by_height(Integer(10)):
# ----> 2     if h(-w).squarefree_part() == Integer(17):
#       3         print(-w,h(-w),h(-w).squarefree_part().factor())
#
# NameError: name 'h' is not defined
