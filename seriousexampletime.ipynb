# %% [markdown]
#     /*    1 */   R<a,b,c> := PolynomialRing(Rationals());
#     /*    2 */   R<a,b,c> := PolynomialRing(Rationals(),3);
#     /*    3 */   T<X>:=PolynomialRing(R);
#     /*    4 */   Y^2+(1+X+X^3+C c*(X+X^2))*Y -
#     /*    5 */     (-C b*C d*X^4+(C b-C d-2*C b*C d)*X^3+(1+3*C b-C b*C d)*X^2+(1+3*C b)*X+C b)
#     /*    6 */   ;
#     /*    7 */   R<b,c,d> := PolynomialRing(Rationals(),3);
#     /*    8 */   T<X>:=PolynomialRing(R);
#     /*    9 */   f;
#     /*   10 */   f:=Y^2+(1+X+X^3+c*(X+X^2))*Y - (-b*d*X^4+(b-d-2*b*d)*X^3+(1+3*b-b*d)*X^2+(1+3*b)*X+b);
#     /*   11 */   f,g:=(1+X+X^3+c*(X+X^2)), (-b*d*X^4+(b-d-2*b*d)*X^3+(1+3*b-b*d)*X^2+(1+3*b)*X+b);
#     /*   12 */   f,g:=[(1+X+X^3+c*(X+X^2)), (-b*d*X^4+(b-d-2*b*d)*X^3+(1+3*b-b*d)*X^2+(1+3*b)*X+b)];
#     /*   13 */   f,g:=Explode([(1+X+X^3+c*(X+X^2)), (-b*d*X^4+(b-d-2*b*d)*X^3+(1+3*b-b*d)*X^2+(1+3*b)*X+b)]);
#     /*   14 */   f;
#     /*   15 */   g;
#     /*   16 */   HyperellipticCurve(g,f)'
#     /*   17 */   HyperellipticCurve(g,f)'
#     /*   18 */   HyperellipticCurve(g,f);
#     /*   19 */   phi := map<R
#     /*   20 */   ;
#     /*   21 */   phi := map<R|f >;
#     /*   22 */   phi := map<R|[0,1,7] >;
#     /*   23 */   phi := map<R->Rationals()|[0,1,7] >;
#     /*   24 */   phi := map<R->Rationals()|0,1,7 >;
#     /*   25 */   R;
#     /*   26 */   phi := hom<R->Rationals()|0,1,7 >;
#     /*   27 */   phi(b)
#     /*   28 */   ;
#     /*   29 */   phi(c);
#     /*   30 */   phi(d);
#     /*   31 */   HH:=yperellipticCurve(g,f);
#     /*   32 */   H:=HyperellipticCurve(g,f);
#     /*   33 */   ChangeRing(H,phi)'
#     /*   34 */   ChangeRing(H,phi);
#     /*   35 */   ChangeRing(phi,H);
#     /*   36 */   ChangeBase(phi,H);
#     /*   37 */   ChangeBase(H,phi);
#     /*   38 */   ChangeRing;
#     /*   39 */   ChangeRing(H,phi);
#     /*   40 */   ChangeRing(H,phi);
#     /*   41 */   ChangeRing;
#     /*   42 */   BaseChange(H, phi);
#     /*   43 */   BaseRing(H);
#     /*   44 */   R;
#     /*   45 */   H;
#     /*   46 */   phi := hom<FractionField(R)->Rationals()|0,1,7 >;
#     /*   47 */   phi := hom<FieldOfFractions(R)->Rationals()|0,1,7 >;
#     /*   48 */   BaseChange(H, phi);
#     /*   49 */   Discriminant(BaseChange(H, phi));
#     /*   50 */   Factorization(Discriminant(BaseChange(H, phi)));
#     /*   51 */   Factorization(Integers()!Discriminant(BaseChange(H, phi)));
#     /*   52 */   phi := hom<FieldOfFractions(R)->Rationals()|1,0,7 >;
#     /*   53 */   Factorization(Integers()!Discriminant(BaseChange(H, phi)));
#     /*   54 */   phi := hom<FieldOfFractions(R)->Rationals()|1,0,5 >;
#     /*   55 */   Factorization(Integers()!Discriminant(BaseChange(H, phi)));
#     /*   56 */   for B,C,D in Integers()
#     /*   57 */   print a , b, c;
#     /*   58 */   for B,C,D in Integers() do
#     /*   59 */   print a,b,c;
#     /*   60 */   end for;
#     /*   61 */   CartesianPower(Integers(),3);
#     /*   62 */   for a,b,c in CartesianPower(Integers(),3) do
#     /*   63 */   print a,b,c;
#     /*   64 */   end for;
#     /*   65 */   for a,b,c in CartesianPower([1..4],3) do
#     /*   66 */   print a,b,c;
#     /*   67 */   end for;
#     /*   68 */   for [a,b,c] in CartesianPower([1..4],3) do
#     /*   69 */   for (a,b,c) in CartesianPower([1..4],3) do
#     /*   70 */   for [*a,b,c]* in CartesianPower([1..4],3) do
#     /*   71 */   for [*a,b,c*] in CartesianPower([1..4],3) do
#     /*   72 */   for A in CartesianPower([1..4],3) do
#     /*   73 */   phi := hom<FieldOfFractions(R)->Rationals()|Explode(A) >;
#     /*   74 */   print Factorization(Integers()!Discriminant(BaseChange(H, phi)));
#     /*   75 */   end for;
#     /*   76 */   for A in CartesianPower([1..4],3) do
#     /*   77 */   phi := hom<FieldOfFractions(R)->Rationals()|A[1],A[2],A[3] >;
#     /*   78 */   print Factorization(Integers()!Discriminant(BaseChange(H, phi)));
#     /*   79 */   end for;
#     /*   80 */   for A in CartesianPower([-4..4],3) do
#     /*   81 */   phi := hom<FieldOfFractions(R)->Rationals()|A[1],A[2],A[3] >;
#     /*   82 */   print Factorization(Integers()!Discriminant(BaseChange(H, phi)));
#     /*   83 */   end for;
#     /*   84 */   H;
#     /*   85 */   IsPowerOf(5,10);
#     /*   86 */   IsPowerOf(5,115);
#     /*   87 */   IsPowerOf(5,25);
#     /*   88 */   IsPowerOf(25,5);
#     /*   89 */   IsPowerOf(Rationals()!25,5);
#     /*   90 */   IsPowerOf(Rationals()!25,Rationals()!5);
#     /*   91 */   for A in CartesianPower([-4..4],3) do
#     /*   92 */   phi := hom<FieldOfFractions(R)->Rationals()|A[1],A[2],A[3] >;
#     /*   93 */   if IsPowerOf(Numerator(Factorization(Integers()!Discriminant(BaseChange(H, phi))), 5) then
#     /*   94 */   for A in CartesianPower([-4..4],3) do
#     /*   95 */   if IsPowerOf(Numerator(Factorization(Integers()!Discriminant(BaseChange(H, phi))), 5)
#     /*   96 */   print (BaseChange(H, phi)),A;
#     /*   97 */   for A in CartesianPower([-4..4],3) do
#     /*   98 */   phi := hom<FieldOfFractions(R)->Rationals()|A[1],A[2],A[3] >;
#     /*   99 */   if IsPowerOf(Numerator(Factorization(Integers()!Discriminant(BaseChange(H, phi))), 5)
#     /*  100 */   then print BaseChange(H, phi),A;
#     /*  101 */   if IsPowerOf(Numerator(Factorization(Integers()!Discriminant(BaseChange(H, phi))), 5)) then
#     /*  102 */   then print BaseChange(H, phi),A;
#     /*  103 */   for A in CartesianPower([-4..4],3) do
#     /*  104 */   phi := hom<FieldOfFractions(R)->Rationals()|A[1],A[2],A[3] >;
#     /*  105 */   if IsPowerOf(Numerator(Factorization(Integers()!Discriminant(BaseChange(H, phi))), 5)) then
#     /*  106 */    print BaseChange(H, phi),A;
#     /*  107 */   end if;
#     /*  108 */   end for;
#     /*  109 */   for A in CartesianPower([-4..4],3) do
#     /*  110 */   phi := hom<FieldOfFractions(R)->Rationals()|A[1],A[2],A[3] >;
#     /*  111 */   if IsPowerOf(((Integers()!Discriminant(BaseChange(H, phi))), 5)) then
#     /*  112 */    print BaseChange(H, phi),A;
#     /*  113 */   end if;
#     /*  114 */   end for;
#     /*  115 */   for A in CartesianPower([-4..4],3) do
#     /*  116 */   phi := hom<FieldOfFractions(R)->Rationals()|A[1],A[2],A[3] >;
#     /*  117 */   if IsPowerOf(Integers()!Discriminant(BaseChange(H, phi)), 5) then
#     /*  118 */    print BaseChange(H, phi),A;
#     /*  119 */   end if;
#     /*  120 */   end for;
#     /*  121 */   for A in CartesianPower([-4..4],3) do
#     /*  122 */   phi := hom<FieldOfFractions(R)->Rationals()|A[1],A[2],A[3] >;
#     /*  123 */   if IsPowerOf(Integers()!Discriminant(BaseChange(H, phi)), 5) then
#     /*  124 */    print BaseChange(H, phi),A, Conductor(BaseChange(H, phi));
#     /*  125 */   end if;
#     /*  126 */   end for;
#     /*  127 */   L := [];
#     /*  128 */   for A in CartesianPower([-4..4],3) do
#     /*  129 */   phi := hom<FieldOfFractions(R)->Rationals()|A[1],A[2],A[3] >;
#     /*  130 */   if IsPowerOf(Integers()!Discriminant(BaseChange(H, phi)), 5) then
#     /*  131 */   Append(~L, BaseChange(H,phi));
#     /*  132 */    print BaseChange(H, phi),A, Conductor(BaseChange(H, phi));
#     /*  133 */   end if ;
#     /*  134 */   end for;
#     /*  135 */   L;
#     /*  136 */   IsIsomorphic(L[1], L[2]);
#     /*  137 */   IsIsomorphic(L[1], L[3]);
#     /*  138 */   IsIsogenous;
#     /*  139 */   IsIsogenousPeriodMatrices;
#     /*  140 */   PeriodMatrix(L[1]);
#     /*  141 */   PeriodMatrix(L[2]);
#     /*  142 */   IsIsogenousPeriodMatrices(PeriodMatrix(L[1]), PeriodMatrix(L[2]));
#     /*  143 */   MinimalDiscriminant(L[1]);
#     /*  144 */   MinimalDiscriminant(L[2]);
#     /*  145 */   Determinant(IsIsogenousPeriodMatrices(PeriodMatrix(L[1]), PeriodMatrix(L[2])));
#     /*  146 */   p,q,r := (IsIsogenousPeriodMatrices(PeriodMatrix(L[1]), PeriodMatrix(L[2])));
#     /*  147 */   Determinant(q);
#     /*  148 */   Determinant(r);
#     /*  149 */   IsIsomorphic;
#     /*  150 */   AnalyticJacobian(L[1]);
#     /*  151 */   WeierstrassModel(L[1]);
#     /*  152 */   HasOddDegreeModel(L[1]);
#     /*  153 */   SimplifiedModel(L[1]);
#     /*  154 */   AnalyticJacobian(SimplifiedModel(L[1]));
#     /*  155 */   A1:=AnalyticJacobian(SimplifiedModel(L[1]));
#     /*  156 */   A2:=AnalyticJacobian(SimplifiedModel(L[2]));
#     /*  157 */   IsIsomorphic(A1,A2);
#     /*  158 */   IsIsomorphic;
#     /*  159 */   AssociativeArray;
#     /*  160 */   AssociativeArray(Integers());
#     /*  161 */   Q:=AssociativeArray(Integers());
#     /*  162 */   Q[1] := 1;
#     /*  163 */   Q;
#     /*  164 */   Q[1];
#     /*  165 */   Q[2];
#     /*  166 */   Keys(Q);
#     /*  167 */   for A in CartesianPower([-5..5],3) do
#     /*  168 */   phi := hom<FieldOfFractions(R)->Rationals()|A[1],A[2],A[3] >;
#     /*  169 */   con := Conductor(BaseChange(H, phi));
#     /*  170 */   if con not in Keys(Q) then Q[con] := [] end if;
#     /*  171 */   for A in CartesianPower([-5..5],3) do
#     /*  172 */   phi := hom<FieldOfFractions(R)->Rationals()|A[1],A[2],A[3] >;
#     /*  173 */   con := Conductor(BaseChange(H, phi));
#     /*  174 */   if not con in Keys(Q) then Q[con] := [] end if;
#     /*  175 */   if not con in Keys(Q) then Q[con] := [] end if;
#     /*  176 */   for A in CartesianPower([-5..5],3) do
#     /*  177 */   phi := hom<FieldOfFractions(R)->Rationals()|A[1],A[2],A[3] >;
#     /*  178 */   con := Conductor(BaseChange(H, phi));
#     /*  179 */   if not con in Keys(Q) then Q[con] := []; end if;
#     /*  180 */   Append(~Q[con], BaseChange(H, phi));
#     /*  181 */   end for;
#     /*  182 */   Q;
#     /*  183 */   Keys(Q);
#     /*  184 */   Q[529];
#     /*  185 */   IsIsomorphic( Q[529][1], Q[529][2]);
#     /*  186 */   IsIsomorphic( Q[529][1], Q[529][3]);
#     /*  187 */   IsIsomorphic( Q[529][1], Q[529][4]);
#     /*  188 */   IsIsomorphic( Q[529][1], Q[529][5]);
#     /*  189 */   IsIsomorphic( Q[529][3], Q[529][5]);
#     /*  190 */   IsIsomorphic( Q[529][4], Q[529][5]);
#     /*  191 */   IsIsomorphic( Q[529][2], Q[529][3]);
#     /*  192 */   IsIsogenousPeriodMatrices ( PeriodMatrix(Q[529][2]), PeriodMatrix(Q[529][3]));
#     /*  193 */   p,q,r:=IsIsogenousPeriodMatrices ( PeriodMatrix(Q[529][2]), PeriodMatrix(Q[529][3]));
#     /*  194 */   Determinant(q);
#     /*  195 */   IsogenyInformation;
#     /*  196 */   IsogenyInformation:Maximal;
#     /*  197 */   L[1];
#     /*  198 */   IsIsogenousPeriodMatrices(PeriodMatrix(L[1]), PeriodMatrix(L[2]));
#     /*  199 */   Correspondence;
#     /*  200 */   p,q,r:=IsIsogenousPeriodMatrices ( PeriodMatrix(Q[529][2]), PeriodMatrix(Q[529][3]));
#     /*  201 */   p,q,r:=IsIsogenousPeriodMatrices ( PeriodMatrix(L[2]), PeriodMatrix(L[1]));
#     /*  202 */   r;
#     /*  203 */   q
#     /*  204 */   ;
#     /*  205 */   IsIsogenousPeriodMatrices;
#     /*  206 */   Correspondence;
#     /*  207 */   Correspondence(L[2],L[1], q;
#     /*  208 */   Correspondence(L[2],L[1], q);
#     /*  209 */   Correspondence(L[2],L[1], r);
#     /*  210 */   Correspondence(L[2],L[1], ChangeRing(q, Rationals()));
#     /*  211 */   q;
#     /*  212 */   ChangeRing(q,Rationals());
#     /*  213 */   ChangeRing(q,RationalsExtra());
#     /*  214 */   Correspondence(L[2],L[1], ChangeRing(q, RationalsExtra()));
#     /*  215 */   Correspondence(L[2],L[1], ChangeRing(r, ComplexFieldExtra()));
#     /*  216 */   L[1];
#     /*  217 */   Correspondence(ChangeRing(L[2],Rationals(E,L[1], ChangeRing(r, ComplexFieldExtra()));
#     /*  218 */   Correspondence(ChangeRing(L[2],RationalsExtra()),ChangeRing(L[1],RationalsExtra()), ChangeRing(r, ComplexFieldExtra()));
#     /*  219 */   Correspondence(ChangeRing(L[2],ComplexFielExtra()),ChangeRing(L[1],RationalsExtra()), ChangeRing(r, ComplexFieldExtra()));
#     /*  220 */   Correspondence(ChangeRing(L[2],ComplexFieldExtra()),ChangeRing(L[1],RationalsExtra()), ChangeRing(r, ComplexFieldExtra()));
#     /*  221 */   Correspondence(ChangeRing(L[2],ComplexFieldExtra()),ChangeRing(L[1],ComplexFieldExtra()), ChangeRing(r, ComplexFieldExtra()));
#     /*  222 */   HeuristicEndomorphismRepresentation(L[1]);
#     /*  223 */   q,r
#     /*  224 */   ;
#     /*  225 */   ChangeRing(R, Integers());
#     /*  226 */   ChangeRing(r, Integers());
#     /*  227 */   r;
#     /*  228 */   rr := Matrix([[3,1],[1,2]]);
#     /*  229 */   HeuristicEndomorphismRepresentation(L[1]);
#     /*  230 */   [*rr,q*];
#     /*  231 */   ChangeRing(r, Integers());
#     /*  232 */   Correspondence(L[2],L[1], [*rr,q*]);
#     /*  233 */   HeuristicEndomorphismRepresentation(L[1]);
#     /*  234 */   HeuristicEndomorphismRepresentation(L[1])[1][1];
#     /*  235 */   Parent(HeuristicEndomorphismRepresentation(L[1])[1][1]);
#     /*  236 */   Parent(HeuristicEndomorphismRepresentation(L[1])[1][2]);
#     /*  237 */   Type(HeuristicEndomorphismRepresentation(L[1])[1][2]);
#     /*  238 */   Type(BaseRing(HeuristicEndomorphismRepresentation(L[1])[1][2]));
#     /*  239 */   BaseRing(rr);'
#     /*  240 */   Type(BaseRing(HeuristicEndomorphismRepresentation(L[1])[1][2]));
#     /*  241 */   BaseRing(rr);
#     /*  242 */   rr := Matrix(Rationals(),[[3,1],[1,2]]);
#     /*  243 */   q;
#     /*  244 */   BaseRing(q);
#     /*  245 */   Correspondence(L[2],L[1], [*rr,ChangeRing(q,Rationals())*]);
#     /*  246 */   Correspondence;
#     /*  247 */   Correspondence(L[2],L[1], [*rr,ChangeRing(q,Rationals())*]:Al:="Divisor");
#     /*  248 */   Correspondence(L[2],L[1], [*rr,ChangeRing(q,Rationals())*]);
#     /*  249 */   Correspondence;
#     /*  250 */   Correspondence:Maximal;
#     /*  251 */   CantorFromMatrixAmbientSplit;
#     /*  252 */   CantorFromMatrixAmbientSplit:Macimal;
#     /*  253 */   CantorFromMatrixAmbientSplit:Maximal;
#     /*  254 */   CantorComposition;
#     /*  255 */   CantorComposition1;
#     /*  256 */   rr;
#     /*  257 */   PeriodMatrix(L[1])*rr;
#     /*  258 */   PeriodMatrix(L[1])*r;
#     /*  259 */   r*PeriodMatrix(L[1]);
#     /*  260 */   r*PeriodMatrix(L[1]);
#     /*  261 */   PeriodMatrix(L[2])*q;
#     /*  262 */   PeriodMatrix(L[2])*ChangeRing(q,ComplexField());
#     /*  263 */   PeriodMatrix(L[2])*ChangeRing(q,ComplexFieldExtra());
#     /*  264 */   q;
#     /*  265 */   L[2];
#     /*  266 */   PeriodMatrix(L[2])*ChangeRing(q,ComplexFieldExtra());
#     /*  267 */   q;
#     /*  268 */   PeriodMatrix(L[2])*ChangeRing(q,RationalsExtra());
#     /*  269 */   PeriodMatrix(L[2]);
#     /*  270 */   PeriodMatrix(L[2])*ChangeRing(q,ComplexField());
#     /*  271 */   PeriodMatrix(L[2])*ChangeRing(q,BaseRing(PeriodMatrix(L[2])));
#     /*  272 */   PeriodMatrix(L[1])*ChangeRing(q,BaseRing(PeriodMatrix(L[2])));
#     /*  273 */   r*PeriodMatrix(L[2]);
#     /*  274 */   r*PeriodMatrix(L[1]);
#     /*  275 */   r*PeriodMatrix(L[1]);
#     /*  276 */   r*PeriodMatrix(L[2])*ChangeRing(q,BaseRing(PeriodMatrix(L[2])));
#     /*  277 */   PeriodMatrix(L[1]);
#     /*  278 */   r*PeriodMatrix(L[1]);
#     /*  279 */   PeriodMatrix(L[2])*ChangeRing(q,BaseRing(PeriodMatrix(L[2])));
#     /*  280 */   PeriodMatrix(L[1])*ChangeRing(q,BaseRing(PeriodMatrix(L[2])));
#     /*  281 */   r*PeriodMatrix(L[2]);
#     /*  282 */   r*PeriodMatrix(L[2]) - PeriodMatrix(L[1])*ChangeRing(q,BaseRing(PeriodMatrix(L[2])));
#     /*  283 */   r;
#     /*  284 */   PeriodMatrix(L[1])*ChangeRing(q,BaseRing(PeriodMatrix(L[2])));
#     /*  285 */   p,q,r:=IsIsogenousPeriodMatrices ( PeriodMatrix(L[1]), PeriodMatrix(L[2]));
#     /*  286 */   p
#     /*  287 */   ;
#     /*  288 */   q;
#     /*  289 */   r;
#     /*  290 */   r*PeriodMatrix(L[1]) - PeriodMatrix(L[2])*ChangeRing(q,BaseRing(PeriodMatrix(L[2])));
#     /*  291 */   r*PeriodMatrix(Q[529][2])// PeriodMatrix(Q[529][3]);
#     /*  292 */   r*PeriodMatrix(Q[529][2])/ PeriodMatrix(Q[529][3]);
#     /*  293 */   ;
#     /*  294 */   ;
#     /*  295 */   r*PeriodMatrix(Q[529][2])/ PeriodMatrix(Q[529][3]);
#     /*  296 */   Solve( r*PeriodMatrix(Q[529][2]), PeriodMatrix(Q[529][3]));
#     /*  297 */   r*PeriodMatrix(Q[529][2]),
#     /*  298 */   ;
#     /*  299 */   r*PeriodMatrix(Q[529][2]),
#     /*  300 */   ;
#     /*  301 */   r*PeriodMatrix(Q[529][2])
#     /*  302 */   ;
#     /*  303 */   Solve;
#     /*  304 */   Solution;
#     /*  305 */   Solution( r*PeriodMatrix(Q[529][2]), PeriodMatrix(Q[529][3]));
#     /*  306 */   Solution( r*PeriodMatrix(Q[529][2]), PeriodMatrix(Q[529][4]));
#     /*  307 */   Solution(PeriodMatrix(Q[529][3]), r*PeriodMatrix(Q[529][2]));
#     /*  308 */   Solution(PeriodMatrix(Q[529][4]), r*PeriodMatrix(Q[529][2]));
#     /*  309 */   Solution(PeriodMatrix(L[2]), r*PeriodMatrix(L[1]));
#     /*  310 */   Solution(PeriodMatrix(L[1]), r*PeriodMatrix(L[2]));
#     /*  311 */   Solution(r*PeriodMatrix(L[2]),PeriodMatrix(L[1]));
#     /*  312 */   Solution(r*PeriodMatrix(L[1]),PeriodMatrix(L[2]));
#     /*  313 */   p,q,r:=IsIsogenousPeriodMatrices ( PeriodMatrix(L[1]), PeriodMatrix(L[2]));
#     /*  314 */   r;
#     /*  315 */   Solution(r*PeriodMatrix(L[2]),PeriodMatrix(L[1]));
#     /*  316 */   r*PeriodMatrix(L[2]) - PeriodMatrix(L[1])*ChangeRing(q,BaseRing(PeriodMatrix(L[2])));
#     /*  317 */   r*PeriodMatrix(L[1]) - PeriodMatrix(L[2])*ChangeRing(q,BaseRing(PeriodMatrix(L[2])));
#     /*  318 */   Solution(r*PeriodMatrix(L[1]),PeriodMatrix(L[1]));
#     /*  319 */   Solution(PeriodMatrix(L[2]),r*PeriodMatrix(L[1]));
#     /*  320 */   Solution;
#     /*  321 */   RationalFunction;
#     /*  322 */   RationalFunctionField;
#     /*  323 */   RationalFunctionField(Rationals());
#     /*  324 */   save "brumer.ws";
#     /*  325 */   Log;
#     /*  326 */   save;
#     /*  327 */   save "brumerexamples.ws";
#     /*  328 */   IsIsogenousPeriodMatrices(PeriodMatrix(L[1]), PeriodMatrix(L[2]));
#     /*  329 */   o,DD:=IsIsogenousPeriodMatrices(PeriodMatrix(L[1]), PeriodMatrix(L[2]));
#     /*  330 */   Determinant(DD);
#     /*  331 */   L;
#     /*  332 */   L[1];
#     /*  333 */   Conductor(L[1]);
#     /*  334 */   IgusaClebschInvariants(L[1]);
#     /*  335 */   IgusaClebschInvariants(L[2]);
#     /*  336 */   magma: R<x> := PolynomialRing(Rationals()); C := HyperellipticCurve(R![0, 0, 1, 2, 2, 2], R![1, 1, 0, 1]);
#     /*  337 */    R<x> := PolynomialRing(Rationals()); C := HyperellipticCurve(R![0, 0, 1, 2, 2, 2], R![1, 1, 0, 1]);
#     /*  338 */   IsIsomorphic(R, L[1]);
#     /*  339 */   IsIsomorphic(C, L[1]);
#     /*  340 */   IgusaClebschInvariants;

# %% [markdown]
# Trying to solve:
#
# $$\Delta (C_{b,c,d}) = \pm 23^n$$
#
# have two modular forms
#
# https://www.lmfdb.org/ModularForm/GL2/Q/holomorphic/23/2/a/a/
#
#     Hyperelliptic Curve defined by y^2 + (x^3 - x^2 + 1)*y = -6*x^4 - 13*x^3 - 14*x^2 - 8*x - 3 over Rational Field
#     <-3, -1, -2> 529
#     Hyperelliptic Curve defined by y^2 + (x^3 + 4*x^2 + 5*x + 1)*y = -6*x^4 - 11*x^3 - 11*x^2 - 5*x - 2 over Rational Field
#     <-2, 4, -3> 529
#     Hyperelliptic Curve defined by y^2 + (x^3 - 2*x^2 - x + 1)*y = -x^3 + x^2 + x over Rational Field
#     <0, -2, 1> 529
#     Hyperelliptic Curve defined by y^2 + (x^3 - x^2 + 1)*y = -x^3 + x^2 + x over Rational Field
#     <0, -1, 1> 529
#     Hyperelliptic Curve defined by y^2 + (x^3 + 4*x^2 + 5*x + 1)*y = x^3 + 4*x^2 + 4*x + 1 over Rational Field
#     <1, 4, 0> 529
#
# https://www.lmfdb.org/ModularForm/GL2/Q/holomorphic/529/2/a/a/

# %%
R<b,c,d> := PolynomialRing(Rationals(),3);
T<X>:=PolynomialRing(R);
f,g:=Explode([(1+X+X^3+c*(X+X^2)), (-b*d*X^4+(b-d-2*b*d)*X^3+(1+3*b-b*d)*X^2+(1+3*b)*X+b)]);
print [f, g];
H:=HyperellipticCurve(g,f);
L:=[];
for A in CartesianPower([-24..24],3) do
    phi := hom<FieldOfFractions(R)->Rationals()|A[1],A[2],A[3] >;
    if Integers()!MinimalDiscriminant(BaseChange(H, phi)) mod 279841 eq 0 and
        IsPowerOf(Integers()!Conductor(BaseChange(H, phi)), 23) then
        Append(~L, BaseChange(H,phi));
        print BaseChange(H, phi),A, Conductor(BaseChange(H, phi));
    end if ;
end for;

# %%
IsIsomorphic(L[1],L[3]);
# Out:
# >> IsIsomorphic(L[1],L[3]);
#                       ^
# Runtime error in '[]': Index 1 (3) should be in the range [1 .. 2]

# %%
Factorization(31236921);
# Out:
# [ <3, 10>, <23, 2> ]
