# %%
R.<a_1,a_2,a_3,a_4,a_6,Z_1,Y_1,X_1,Z_2,Y_2,X_2> = PolynomialRing(QQ)
Rq = R.quotient_ring(R.ideal([Z_1*Y_1^2 + a_1*X_1*Y_1*Z_1 + a_3 *Y_1*Z_1^2 - X_1^3 - a_2 * X_1^2 * Z_1 - a_4 * X_1 * Z_1^2 - a_6 * Z_1^3,
                              Z_2*Y_2^2 + a_1*X_2*Y_2*Z_2 + a_3 *Y_2*Z_2^2 - X_2^3 - a_2 * X_2^2 * Z_2 - a_4 * X_2 * Z_2^2 - a_6 * Z_2^3 ]))
print(Rq.fraction_field().gens())
a_1,a_2,a_3,a_4,a_6,z_1,y_1,x_1,z_2,y_2,x_2 = R.fraction_field().gens()
z_0 =((x_1 * z_2 - z_1 * x_2)^3)/ (z_1 * z_2)
print(z_0)
λ = (y_1 * z_2 - y_2 * z_1)/(x_1 * z_2 - x_2 * z_1)
show(λ)
ν = - (y_1 * x_2 - y_2 * x_1)/(x_1 * z_2 - x_2 * z_1)
show(ν)
f = λ^2 + a_1 * λ - (x_1 * z_2 + x_2 * z_1)/(z_1*z_2) - a_2
g = -(λ + a_1)*f - ν - a_3
# Out:
# (a_1bar, a_2bar, a_3bar, a_4bar, a_6bar, Z_1bar, Y_1bar, X_1bar, Z_2bar, Y_2bar, X_2bar)
# (X_1^3*Z_2^3 - 3*Z_1*X_1^2*Z_2^2*X_2 + 3*Z_1^2*X_1*Z_2*X_2^2 - Z_1^3*X_2^3)/(Z_1*Z_2)
# (Y_1*Z_2 - Z_1*Y_2)/(X_1*Z_2 - Z_1*X_2)
# (X_1*Y_2 - Y_1*X_2)/(X_1*Z_2 - Z_1*X_2)

# %%
(z_1*y_1^2 + a_1*x_1*y_1*z_1 + a_3 *y_1*z_1^2 - x_1^3 - a_2 * x_1^2 * z_1 - a_4 * x_1 * z_1^2)
# Out:
# a_3bar*Z_1bar^2*Y_1bar - a_4bar*Z_1bar^2*X_1bar + a_1bar*Z_1bar*Y_1bar*X_1bar - a_2bar*Z_1bar*X_1bar^2 + Z_1bar*Y_1bar^2 - X_1bar^3

# %%
z_0
# Out:
# (X_1bar^3*Z_2bar^3 - 3*Z_1bar*X_1bar^2*Z_2bar^2*X_2bar + 3*Z_1bar^2*X_1bar*Z_2bar*X_2bar^2 - Z_1bar^3*X_2bar^3)/(Z_1bar*Z_2bar)

# %%
X_1^3 == Z_1*Y_1^2 + a_1*X_1*Y_1*Z_1 + a_3 *Y_1*Z_1^2  - a_2 * X_1^2 * Z_1 - a_4 * X_1 * Z_1^2 - a_6 * Z_1^3
# Out:
# True

# %%
X_2^3 == Z_2*Y_2^2 + a_1*X_2*Y_2*Z_2 + a_3 *Y_2*Z_2^2  - a_2 * X_2^2 * Z_2 - a_4 * X_2 * Z_2^2 - a_6 * Z_2^3
# Out:
# True

# %%
z_0
# Out:
# (X_1bar^3*Z_2bar^3 - 3*Z_1bar*X_1bar^2*Z_2bar^2*X_2bar + 3*Z_1bar^2*X_1bar*Z_2bar*X_2bar^2 - Z_1bar^3*X_2bar^3)/(Z_1bar*Z_2bar)

# %% [markdown]
# Rewrite z_0 without division

# %%
Z_0 = (-Z_1^2*(Y_2^2 + a_1*X_2*Y_2 + a_3 *Y_2*Z_2^1  - a_2 * X_2^2 - a_4 * X_2 * Z_2^1 - a_6 * Z_2^2) + 3*X_1*Z_1^1*X_2^2 - 3*X_1^2*X_2*Z_2^1 + (Y_1^2 + a_1*X_1*Y_1 + a_3 *Y_1*Z_1^1  - a_2 * X_1^2 - a_4 * X_1 * Z_1^1 - a_6 * Z_1^2)*Z_2^2)
Z_0
# Out:
# a_3bar*Z_1bar*Y_1bar*Z_2bar^2 - a_4bar*Z_1bar*X_1bar*Z_2bar^2 + a_1bar*Y_1bar*X_1bar*Z_2bar^2 - a_2bar*X_1bar^2*Z_2bar^2 - a_3bar*Z_1bar^2*Z_2bar*Y_2bar + a_4bar*Z_1bar^2*Z_2bar*X_2bar - a_1bar*Z_1bar^2*Y_2bar*X_2bar + a_2bar*Z_1bar^2*X_2bar^2 + Y_1bar^2*Z_2bar^2 - Z_1bar^2*Y_2bar^2 - 3*X_1bar^2*Z_2bar*X_2bar + 3*Z_1bar*X_1bar*X_2bar^2

# %%
z_0 == Z_0
# Out:
# True

# %%
Z_0 + (3*X_1*X_2*(X_1*Z_2-X_2*Z_1)-(Y_1*Z_2+Y_2*Z_1)*(Y_1*Z_2-Y_2*Z_1)\
            +a_1*(X_1*Y_2-X_2*Y_1)*Z_1*Z_2-a_1*(X_1*Z_2-X_2*Z_1)*(Y_1*Z_2+Y_2*Z_1)\
            +a_2*(X_1*Z_2+X_2*Z_1)*(X_1*Z_2-X_2*Z_1)-a_3*(Y_1*Z_2-Y_2*Z_1)*Z_1*Z_2\
            +a_4*(X_1*Z_2-X_2*Z_1)*Z_1*Z_2)
# Out:
# 0

# %%
x_31 = f * Z_0#*(Z_1*Z_2)^2
x_31
# Out:
# (-a_3bar*Z_1bar*Y_1bar*X_1bar^4*Z_2bar^6 + a_4bar*Z_1bar*X_1bar^5*Z_2bar^6 + a_3bar*Z_1bar^2*X_1bar^4*Z_2bar^5*Y_2bar - a_1bar*Z_1bar*X_1bar^5*Z_2bar^5*Y_2bar - a_4bar*Z_1bar^2*X_1bar^4*Z_2bar^5*X_2bar - 5*a_1bar*Z_1bar*Y_1bar*X_1bar^4*Z_2bar^5*X_2bar + 6*a_2bar*Z_1bar*X_1bar^5*Z_2bar^5*X_2bar + 6*a_1bar*Z_1bar^2*X_1bar^4*Z_2bar^4*Y_2bar*X_2bar + 10*a_1bar*Z_1bar^2*Y_1bar*X_1bar^3*Z_2bar^4*X_2bar^2 - 16*a_2bar*Z_1bar^2*X_1bar^4*Z_2bar^4*X_2bar^2 - 10*a_1bar*Z_1bar^3*X_1bar^3*Z_2bar^3*Y_2bar*X_2bar^2 - 10*a_1bar*Z_1bar^3*Y_1bar*X_1bar^2*Z_2bar^3*X_2bar^3 + 20*a_2bar*Z_1bar^3*X_1bar^3*Z_2bar^3*X_2bar^3 + 10*a_1bar*Z_1bar^4*X_1bar^2*Z_2bar^2*Y_2bar*X_2bar^3 + a_3bar*Z_1bar^5*Y_1bar*Z_2bar^2*X_2bar^4 - a_4bar*Z_1bar^5*X_1bar*Z_2bar^2*X_2bar^4 + 6*a_1bar*Z_1bar^4*Y_1bar*X_1bar*Z_2bar^2*X_2bar^4 - 16*a_2bar*Z_1bar^4*X_1bar^2*Z_2bar^2*X_2bar^4 - a_3bar*Z_1bar^6*Z_2bar*Y_2bar*X_2bar^4 - 5*a_1bar*Z_1bar^5*X_1bar*Z_2bar*Y_2bar*X_2bar^4 + a_4bar*Z_1bar^6*Z_2bar*X_2bar^5 - a_1bar*Z_1bar^5*Y_1bar
# ...

# %%
z_31 = Z_0
z_31
# Out:
# a_3bar*Z_1bar*Y_1bar*Z_2bar^2 - a_4bar*Z_1bar*X_1bar*Z_2bar^2 + a_1bar*Y_1bar*X_1bar*Z_2bar^2 - a_2bar*X_1bar^2*Z_2bar^2 - a_3bar*Z_1bar^2*Z_2bar*Y_2bar + a_4bar*Z_1bar^2*Z_2bar*X_2bar - a_1bar*Z_1bar^2*Y_2bar*X_2bar + a_2bar*Z_1bar^2*X_2bar^2 + Y_1bar^2*Z_2bar^2 - Z_1bar^2*Y_2bar^2 - 3*X_1bar^2*Z_2bar*X_2bar + 3*Z_1bar*X_1bar*X_2bar^2

# %%
x_31==-((x_1*y_2-x_2*y_1)*(y_1*z_2+y_2*z_1)+(x_1*z_2-x_2*z_1)*y_1*y_2\
            +a_1*x_1*x_2*(y_1*z_2-y_2*z_1)+a_1*(x_1*y_2-x_2*y_1)*(x_1*z_2+x_2*z_1)\
            -a_2*x_1*x_2*(x_1*z_2-x_2*z_1)+a_3*(x_1*y_2-x_2*y_1)*z_1*z_2\
            +a_3*(x_1*z_2-x_2*z_1)*(y_1*z_2+y_2*z_1)\
            -a_4*(x_1*z_2+x_2*z_1)*(x_1*z_2-x_2*z_1)\
            -3*a_6*(x_1*z_2-x_2*z_1)*z_1*z_2)
# Out:
# True

# %%
y_31 = g * Z_0
show(y_31)
# Out:
# (a_1bar*a_3bar*Z_1bar*Y_1bar*X_1bar^4*Z_2bar^6 - a_1bar*a_4bar*Z_1bar*X_1bar^5*Z_2bar^6 - a_1bar*a_3bar*Z_1bar^2*X_1bar^4*Z_2bar^5*Y_2bar + a_1bar^2*Z_1bar*X_1bar^5*Z_2bar^5*Y_2bar + a_1bar*a_4bar*Z_1bar^2*X_1bar^4*Z_2bar^5*X_2bar + 5*a_1bar^2*Z_1bar*Y_1bar*X_1bar^4*Z_2bar^5*X_2bar - 6*a_1bar*a_2bar*Z_1bar*X_1bar^5*Z_2bar^5*X_2bar - 6*a_1bar^2*Z_1bar^2*X_1bar^4*Z_2bar^4*Y_2bar*X_2bar - 10*a_1bar^2*Z_1bar^2*Y_1bar*X_1bar^3*Z_2bar^4*X_2bar^2 + 16*a_1bar*a_2bar*Z_1bar^2*X_1bar^4*Z_2bar^4*X_2bar^2 + 10*a_1bar^2*Z_1bar^3*X_1bar^3*Z_2bar^3*Y_2bar*X_2bar^2 + 10*a_1bar^2*Z_1bar^3*Y_1bar*X_1bar^2*Z_2bar^3*X_2bar^3 - 20*a_1bar*a_2bar*Z_1bar^3*X_1bar^3*Z_2bar^3*X_2bar^3 - 10*a_1bar^2*Z_1bar^4*X_1bar^2*Z_2bar^2*Y_2bar*X_2bar^3 - a_1bar*a_3bar*Z_1bar^5*Y_1bar*Z_2bar^2*X_2bar^4 + a_1bar*a_4bar*Z_1bar^5*X_1bar*Z_2bar^2*X_2bar^4 - 6*a_1bar^2*Z_1bar^4*Y_1bar*X_1bar*Z_2bar^2*X_2bar^4 + 16*a_1bar*a_2bar*Z_1bar^4*X_1bar^2*Z_2bar^2*X_2bar^4 + a_1bar*a_3bar*Z_1bar^6*Z_2bar*Y_2bar*X_2bar^4 + 5*a_1bar^2*Z_1
# ...

# %%
y_31 ==- (-3*x_1*x_2*(x_1*y_2-x_2*y_1)\
            -y_1*y_2*(y_1*z_2-y_2*z_1)-2*a_1*(x_1*z_2-x_2*z_1)*y_1*y_2\
            +(a_1^2+3*a_2)*x_1*x_2*(y_1*z_2-y_2*z_1)\
            -(a_1^2+a_2)*(x_1*y_2+x_2*y_1)*(x_1*z_2-x_2*z_1)\
            +(a_1*a_2-3*a_3)*x_1*x_2*(x_1*z_2-x_2*z_1)\
            -(2*a_1*a_3+a_4)*(x_1*y_2-x_2*y_1)*z_1*z_2\
            +a_4*(x_1*z_2+x_2*z_1)*(y_1*z_2-y_2*z_1)\
            +(a_1*a_4-a_2*a_3)*(x_1*z_2+x_2*z_1)*(x_1*z_2-x_2*z_1)\
            +(a_3^2+3*a_6)*(y_1*z_2-y_2*z_1)*z_1*z_2\
            +(3*a_1*a_6-a_3*a_4)*(x_1*z_2-x_2*z_1)*z_1*z_2)
# Out:
# True

# %%
z_0
# Out:
# (X_1bar^3*Z_2bar^3 - 3*Z_1bar*X_1bar^2*Z_2bar^2*X_2bar + 3*Z_1bar^2*X_1bar*Z_2bar*X_2bar^2 - Z_1bar^3*X_2bar^3)/(Z_1bar*Z_2bar)

# %%
κ = (y_1 * z_2 + y_2 * z_1 + a_1 * x_2 * z_1 + a_3 * z_1 * z_2)/(x_1*z_2 - x_2 * z_1)
show(κ)
μ = - (y_1 * x_2 + y_2 * x_1 + a_1 * x_1 * x_2 + a_3 * x_1 * z_2)/(x_1 * z_2 - x_2 * z_1)
show(μ)
sxz = κ^2 + a_1 * κ - (x_1 * z_2 + x_2 * z_1)/(z_1 * z_2) - a_2
syz = -(a_1 + κ) * sxz - μ - a_3
# Out:
# (a_3bar*Z_1bar*Z_2bar + a_1bar*Z_1bar*X_2bar + Y_1bar*Z_2bar + Z_1bar*Y_2bar)/(X_1bar*Z_2bar - Z_1bar*X_2bar)
# (-a_3bar*X_1bar*Z_2bar - a_1bar*X_1bar*X_2bar - X_1bar*Y_2bar - Y_1bar*X_2bar)/(X_1bar*Z_2bar - Z_1bar*X_2bar)

# %%
syz
# Out:
# (-a_3bar^3*Z_1bar^4*X_1bar^2*Z_2bar^6 - 2*a_1bar*a_3bar^2*Z_1bar^3*X_1bar^3*Z_2bar^6 - a_1bar^2*a_3bar*Z_1bar^2*X_1bar^4*Z_2bar^6 + 2*a_3bar^3*Z_1bar^5*X_1bar*Z_2bar^5*X_2bar + 3*a_1bar*a_3bar^2*Z_1bar^4*X_1bar^2*Z_2bar^5*X_2bar - a_1bar^3*Z_1bar^2*X_1bar^4*Z_2bar^5*X_2bar - a_3bar^3*Z_1bar^6*Z_2bar^4*X_2bar^2 + 3*a_1bar^2*a_3bar*Z_1bar^4*X_1bar^2*Z_2bar^4*X_2bar^2 + 2*a_1bar^3*Z_1bar^3*X_1bar^3*Z_2bar^4*X_2bar^2 - a_1bar*a_3bar^2*Z_1bar^6*Z_2bar^3*X_2bar^3 - 2*a_1bar^2*a_3bar*Z_1bar^5*X_1bar*Z_2bar^3*X_2bar^3 - a_1bar^3*Z_1bar^4*X_1bar^2*Z_2bar^3*X_2bar^3 - 3*a_3bar*a_4bar*Z_1bar^3*X_1bar^3*Z_2bar^6 - 2*a_2bar*a_3bar*Z_1bar^2*X_1bar^4*Z_2bar^6 - a_1bar*a_4bar*Z_1bar^2*X_1bar^4*Z_2bar^6 - 6*a_3bar^2*Z_1bar^4*X_1bar^2*Z_2bar^5*Y_2bar - 5*a_1bar*a_3bar*Z_1bar^3*X_1bar^3*Z_2bar^5*Y_2bar - a_1bar^2*Z_1bar^2*X_1bar^4*Z_2bar^5*Y_2bar + 9*a_3bar*a_4bar*Z_1bar^4*X_1bar^2*Z_2bar^5*X_2bar + 2*a_2bar*a_3bar*Z_1bar^3*X_1bar^3*Z_2bar^5*X_2bar + a_1bar*a_4bar*Z_1bar^3*X_1bar^3*Z_2bar^5*X_2bar - 4*
# ...

# %%
x_32 = x_31 * syz
x_32
# Out:
# (a_2bar*a_3bar^3*Z_1bar^4*X_1bar^8*Z_2bar^12 - a_1bar*a_3bar^2*a_4bar*Z_1bar^4*X_1bar^8*Z_2bar^12 + a_1bar*a_2bar*a_3bar^2*Z_1bar^3*X_1bar^9*Z_2bar^12 - a_1bar^2*a_3bar*a_4bar*Z_1bar^3*X_1bar^9*Z_2bar^12 + a_1bar^2*a_3bar^2*Z_1bar^4*X_1bar^8*Z_2bar^11*Y_2bar + a_1bar^3*a_3bar*Z_1bar^3*X_1bar^9*Z_2bar^11*Y_2bar - 8*a_2bar*a_3bar^3*Z_1bar^5*X_1bar^7*Z_2bar^11*X_2bar + 8*a_1bar*a_3bar^2*a_4bar*Z_1bar^5*X_1bar^7*Z_2bar^11*X_2bar - 8*a_1bar*a_2bar*a_3bar^2*Z_1bar^4*X_1bar^8*Z_2bar^11*X_2bar + 7*a_1bar^2*a_3bar*a_4bar*Z_1bar^4*X_1bar^8*Z_2bar^11*X_2bar - a_1bar^3*a_4bar*Z_1bar^3*X_1bar^9*Z_2bar^11*X_2bar - 8*a_1bar^2*a_3bar^2*Z_1bar^5*X_1bar^7*Z_2bar^10*Y_2bar*X_2bar - 7*a_1bar^3*a_3bar*Z_1bar^4*X_1bar^8*Z_2bar^10*Y_2bar*X_2bar + a_1bar^4*Z_1bar^3*X_1bar^9*Z_2bar^10*Y_2bar*X_2bar + 28*a_2bar*a_3bar^3*Z_1bar^6*X_1bar^6*Z_2bar^10*X_2bar^2 - 28*a_1bar*a_3bar^2*a_4bar*Z_1bar^6*X_1bar^6*Z_2bar^10*X_2bar^2 + 28*a_1bar*a_2bar*a_3bar^2*Z_1bar^5*X_1bar^7*Z_2bar^10*X_2bar^2 - 20*a_1bar^2*a_3bar*a_4b
# ...

# %%
x_32  +(y_1*y_2*(x_1*y_2+x_2*y_1)+a_1*(2*x_1*y_2+x_2*y_1)*x_2*y_1+a_1^2*x_1*x_2^2*y_1\
            -a_2*x_1*x_2*(x_1*y_2+x_2*y_1)-a_1*a_2*x_1^2*x_2^2+a_3*x_2*y_1*(y_1*z_2+2*y_2*z_1)\
            +a_1*a_3*x_1*x_2*(y_1*z_2-y_2*z_1)-a_1*a_3*(x_1*y_2+x_2*y_1)*(x_1*z_2-x_2*z_1)\
            -a_4*x_1*x_2*(y_1*z_2+y_2*z_1)-a_4*(x_1*y_2+x_2*y_1)*(x_1*z_2+x_2*z_1)\
            -a_1^2*a_3*x_1^2*x_2*z_2-a_1*a_4*x_1*x_2*(2*x_1*z_2+x_2*z_1)\
            -a_2*a_3*x_1*x_2^2*z_1-a_3^2*x_1*z_2*(2*y_2*z_1+y_1*z_2)\
            -3*a_6*(x_1*y_2+x_2*y_1)*z_1*z_2\
            -3*a_6*(x_1*z_2+x_2*z_1)*(y_1*z_2+y_2*z_1)-a_1*a_3^2*x_1*z_2*(x_1*z_2+2*x_2*z_1)\
            -3*a_1*a_6*x_1*z_2*(x_1*z_2+2*x_2*z_1)-a_3*a_4*(2*x_1*z_2+x_2*z_1)*x_2*z_1 +comment("THIS BIT BAD") \
            -(a_1^2*a_6-a_1*a_3*a_4+a_2*a_3^2+4*a_2*a_6-a_4^2)*(y_1*z_2+y_2*z_1)*z_1*z_2\
            -(a_1^3*a_6-a_1^2*a_3*a_4+a_1*a_2*a_3^2+4*a_1*a_2*a_6-a_1*a_4^2)*x_1*z_1*z_2^2\
            -a_3^3*(x_1*z_2+x_2*z_1)*z_1*z_2-3*a_3*a_6*(x_1*z_2+2*x_2*z_1)*z_1*z_2\
            -(a_1^2*a_3*a_6-a_1*a_3^2*a_4+a_2*a_3^3+4*a_2*a_3*a_6-a_3*a_4^2)*z_1^2*z_2^2)
# Out:
# 0

# %%
(3*a_3*a_4*Z_1^3*X_1^9*Z_2^11*X_2 - 25*a_3*a_4*Z_1^4*X_1^8*Z_2^10*X_2^2 + 92*a_3*a_4*Z_1^5*X_1^7*Z_2^9*X_2^3 - 196*a_3*a_4*Z_1^6*X_1^6*Z_2^8*X_2^4 + 266*a_3*a_4*Z_1^7*X_1^5*Z_2^7*X_2^5 - 238*a_3*a_4*Z_1^8*X_1^4*Z_2^6*X_2^6 + 140*a_3*a_4*Z_1^9*X_1^3*Z_2^5*X_2^7 - 52*a_3*a_4*Z_1^10*X_1^2*Z_2^4*X_2^8 + 11*a_3*a_4*Z_1^11*X_1*Z_2^3*X_2^9 - a_3*a_4*Z_1^12*Z_2^2*X_2^10)/ (Z_1^2*X_1^8*Z_2^10 - 8*Z_1^3*X_1^7*Z_2^9*X_2 + 28*Z_1^4*X_1^6*Z_2^8*X_2^2 - 56*Z_1^5*X_1^5*Z_2^7*X_2^3 + 70*Z_1^6*X_1^4*Z_2^6*X_2^4 - 56*Z_1^7*X_1^3*Z_2^5*X_2^5 + 28*Z_1^8*X_1^2*Z_2^4*X_2^6 - 8*Z_1^9*X_1*Z_2^3*X_2^7 + Z_1^10*Z_2^2*X_2^8)
# Out:
# 3*a_3*a_4*Z_1*X_1*Z_2*X_2 - a_3*a_4*Z_1^2*X_2^2

# %% [markdown]
# so it seems in Bosma-Lenstra p. 237
# $$
# +a_{3} a_{4}\left(X_{1} Z_{2}-2 X_{2} Z_{1}\right) X_{2} Z_{1}
# $$
# should be
# $$
# -a_{3} a_{4}\left(2X_{1} Z_{2} + X_{2} Z_{1}\right) X_{2} Z_{1}
# $$

# %%
y_32 = y_31 * syz
y_32
# Out:
# (-a_1bar*a_2bar*a_3bar^3*Z_1bar^4*X_1bar^10*Z_2bar^14 + a_1bar^2*a_3bar^2*a_4bar*Z_1bar^4*X_1bar^10*Z_2bar^14 - a_1bar^2*a_2bar*a_3bar^2*Z_1bar^3*X_1bar^11*Z_2bar^14 + a_1bar^3*a_3bar*a_4bar*Z_1bar^3*X_1bar^11*Z_2bar^14 - a_1bar^3*a_3bar^2*Z_1bar^4*X_1bar^10*Z_2bar^13*Y_2bar - a_1bar^4*a_3bar*Z_1bar^3*X_1bar^11*Z_2bar^13*Y_2bar + 10*a_1bar*a_2bar*a_3bar^3*Z_1bar^5*X_1bar^9*Z_2bar^13*X_2bar - 10*a_1bar^2*a_3bar^2*a_4bar*Z_1bar^5*X_1bar^9*Z_2bar^13*X_2bar + 10*a_1bar^2*a_2bar*a_3bar^2*Z_1bar^4*X_1bar^10*Z_2bar^13*X_2bar - 9*a_1bar^3*a_3bar*a_4bar*Z_1bar^4*X_1bar^10*Z_2bar^13*X_2bar + a_1bar^4*a_4bar*Z_1bar^3*X_1bar^11*Z_2bar^13*X_2bar + 10*a_1bar^3*a_3bar^2*Z_1bar^5*X_1bar^9*Z_2bar^12*Y_2bar*X_2bar + 9*a_1bar^4*a_3bar*Z_1bar^4*X_1bar^10*Z_2bar^12*Y_2bar*X_2bar - a_1bar^5*Z_1bar^3*X_1bar^11*Z_2bar^12*Y_2bar*X_2bar - 45*a_1bar*a_2bar*a_3bar^3*Z_1bar^6*X_1bar^8*Z_2bar^12*X_2bar^2 + 45*a_1bar^2*a_3bar^2*a_4bar*Z_1bar^6*X_1bar^8*Z_2bar^12*X_2bar^2 - 45*a_1bar^2*a_2bar*a_3bar^2*Z_1bar^5*X_1b
# ...

# %%
def comment(a):
    return 0

# %%
y_32 + ( y_1^2*y_2^2+a_1*x_2*y_1^2*y_2+(a_1*a_2-3*a_3)*x_1*x_2^2*y_1\
            +a_3*y_1^2*y_2*z_2-(a_2^2-3*a_4)*x_1^2*x_2^2\
            +(a_1*a_4-a_2*a_3)*(2*x_1*z_2+x_2*z_1)*x_2*y_1\
            +(a_1^2*a_4-2*a_1*a_2*a_3+3*a_3^2)*x_1^2*x_2*z_2\
            -(a_2*a_4-9*a_6)*x_1*x_2*(x_1*z_2+x_2*z_1)\
            +(3*a_1*a_6-a_3*a_4)*(x_1*z_2+2*x_2*z_1)*y_1*z_2\
            +(3*a_1^2*a_6-2*a_1*a_3*a_4+a_2*a_3^2+3*a_2*a_6-a_4^2)*x_1*z_2*(x_1*z_2+2*x_2*z_1)\
            +(3*a_2*a_6-a_4^2)*x_2 * z_1 * (2*x_1*z_2 + z_1*x_2) + comment("THIS LINE BAD")\
            +(a_1^3*a_6-a_1^2*a_3*a_4+a_1*a_2*a_3^2-a_1*a_4^2+4*a_1*a_2*a_6-a_3^3-3*a_3*a_6)*y_1*z_1*z_2^2\
            +(a_1^4*a_6-a_1^3*a_3*a_4+5*a_1^2*a_2*a_6+a_1^2*a_2*a_3^2-a_1*a_2*a_3*a_4-a_1*a_3^3-3*a_1*a_3*a_6\
            -a_1^2*a_4^2+a_2^2*a_3^2-a_2*a_4^2+4*a_2^2*a_6-a_3^2*a_4-3*a_4*a_6)*x_1*z_1*z_2^2\
            +(a_1^2*a_2*a_6-a_1*a_2*a_3*a_4+3*a_1*a_3*a_6+a_2^2*a_3^2-a_2*a_4^2\
            +4*a_2^2*a_6-2*a_3^2*a_4-3*a_4*a_6)*x_2*z_1^2*z_2\
            +(a_1^3*a_3*a_6-a_1^2*a_3^2*a_4+a_1^2*a_4*a_6+a_1*a_2*a_3^3\
            +4*a_1*a_2*a_3*a_6-2*a_1*a_3*a_4^2+a_2*a_3^2*a_4\
            +4*a_2*a_4*a_6-a_3^4-6*a_3^2*a_6-a_4^3-9*a_6^2)*z_1^2*z_2^2)
# Out:
# 0

# %%
(a_4^2*Z_1^2*X_1^12*Z_2^14 - 3*a_2*a_3*Z_1^2*X_1^12*Z_2^13*Y_2 - 8*a_4^2*Z_1^3*X_1^11*Z_2^13*X_2 + 3*a_2*a_4*Z_1^2*X_1^12*Z_2^13*X_2 + 24*a_2*a_3*Z_1^3*X_1^11*Z_2^12*Y_2*X_2 - 3*a_1*a_2*Z_1^2*X_1^12*Z_2^12*Y_2*X_2 + 25*a_4^2*Z_1^4*X_1^10*Z_2^12*X_2^2 - 24*a_2*a_4*Z_1^3*X_1^11*Z_2^12*X_2^2 + 3*a_2^2*Z_1^2*X_1^12*Z_2^12*X_2^2 - 75*a_2*a_3*Z_1^4*X_1^10*Z_2^11*Y_2*X_2^2 + 24*a_1*a_2*Z_1^3*X_1^11*Z_2^11*Y_2*X_2^2 - 30*a_4^2*Z_1^5*X_1^9*Z_2^11*X_2^3 + 75*a_2*a_4*Z_1^4*X_1^10*Z_2^11*X_2^3 - 24*a_2^2*Z_1^3*X_1^11*Z_2^11*X_2^3 + 90*a_2*a_3*Z_1^5*X_1^9*Z_2^10*Y_2*X_2^3 - 75*a_1*a_2*Z_1^4*X_1^10*Z_2^10*Y_2*X_2^3 - 30*a_4^2*Z_1^6*X_1^8*Z_2^10*X_2^4 - 90*a_2*a_4*Z_1^5*X_1^9*Z_2^10*X_2^4 + 75*a_2^2*Z_1^4*X_1^10*Z_2^10*X_2^4 + 90*a_2*a_3*Z_1^6*X_1^8*Z_2^9*Y_2*X_2^4 + 90*a_1*a_2*Z_1^5*X_1^9*Z_2^9*Y_2*X_2^4 + 168*a_4^2*Z_1^7*X_1^7*Z_2^9*X_2^5 - 90*a_2*a_4*Z_1^6*X_1^8*Z_2^9*X_2^5 - 90*a_2^2*Z_1^5*X_1^9*Z_2^9*X_2^5 - 504*a_2*a_3*Z_1^7*X_1^7*Z_2^8*Y_2*X_2^5 + 90*a_1*a_2*Z_1^6*X_1^8*Z_2^8*Y_2*X_2^5 - 294*a_4^2*Z_1^8*X_1^6*Z_2^8*X_2^6 + 504*a_2*a_4*Z_1^7*X_1^7*Z_2^8*X_2^6 - 90*a_2^2*Z_1^6*X_1^8*Z_2^8*X_2^6 + 882*a_2*a_3*Z_1^8*X_1^6*Z_2^7*Y_2*X_2^6 - 504*a_1*a_2*Z_1^7*X_1^7*Z_2^7*Y_2*X_2^6 + 300*a_4^2*Z_1^9*X_1^5*Z_2^7*X_2^7 - 882*a_2*a_4*Z_1^8*X_1^6*Z_2^7*X_2^7 + 504*a_2^2*Z_1^7*X_1^7*Z_2^7*X_2^7 - 900*a_2*a_3*Z_1^9*X_1^5*Z_2^6*Y_2*X_2^7 + 882*a_1*a_2*Z_1^8*X_1^6*Z_2^6*Y_2*X_2^7 - 195*a_4^2*Z_1^10*X_1^4*Z_2^6*X_2^8 + 900*a_2*a_4*Z_1^9*X_1^5*Z_2^6*X_2^8 - 882*a_2^2*Z_1^8*X_1^6*Z_2^6*X_2^8 + 585*a_2*a_3*Z_1^10*X_1^4*Z_2^5*Y_2*X_2^8 - 900*a_1*a_2*Z_1^9*X_1^5*Z_2^5*Y_2*X_2^8 + 80*a_4^2*Z_1^11*X_1^3*Z_2^5*X_2^9 - 585*a_2*a_4*Z_1^10*X_1^4*Z_2^5*X_2^9 + 900*a_2^2*Z_1^9*X_1^5*Z_2^5*X_2^9 - 240*a_2*a_3*Z_1^11*X_1^3*Z_2^4*Y_2*X_2^9 + 585*a_1*a_2*Z_1^10*X_1^4*Z_2^4*Y_2*X_2^9 - 19*a_4^2*Z_1^12*X_1^2*Z_2^4*X_2^10 + 240*a_2*a_4*Z_1^11*X_1^3*Z_2^4*X_2^10 - 585*a_2^2*Z_1^10*X_1^4*Z_2^4*X_2^10 + 57*a_2*a_3*Z_1^12*X_1^2*Z_2^3*Y_2*X_2^10 - 240*a_1*a_2*Z_1^11*X_1^3*Z_2^3*Y_2*X_2^10 + 2*a_4^2*Z_1^13*X_1*Z_2^3*X_2^11 - 57*a_2*a_4*Z_1^12*X_1^2*Z_2^3*X_2^11 + 240*a_2^2*Z_1^11*X_1^3*Z_2^3*X_2^11 - 6*a_2*a_3*Z_1^13*X_1*Z_2^2*Y_2*X_2^11 + 57*a_1*a_2*Z_1^12*X_1^2*Z_2^2*Y_2*X_2^11 + 6*a_2*a_4*Z_1^13*X_1*Z_2^2*X_2^12 - 57*a_2^2*Z_1^12*X_1^2*Z_2^2*X_2^12 - 6*a_1*a_2*Z_1^13*X_1*Z_2*Y_2*X_2^12 + 6*a_2^2*Z_1^13*X_1*Z_2*X_2^13 - 3*a_2*Z_1^2*X_1^12*Z_2^12*Y_2^2 + 24*a_2*Z_1^3*X_1^11*Z_2^11*Y_2^2*X_2 - 75*a_2*Z_1^4*X_1^10*Z_2^10*Y_2^2*X_2^2 + 3*a_2*Z_1^2*X_1^12*Z_2^11*X_2^3 + 90*a_2*Z_1^5*X_1^9*Z_2^9*Y_2^2*X_2^3 - 24*a_2*Z_1^3*X_1^11*Z_2^10*X_2^4 + 90*a_2*Z_1^6*X_1^8*Z_2^8*Y_2^2*X_2^4 + 75*a_2*Z_1^4*X_1^10*Z_2^9*X_2^5 - 504*a_2*Z_1^7*X_1^7*Z_2^7*Y_2^2*X_2^5 - 90*a_2*Z_1^5*X_1^9*Z_2^8*X_2^6 + 882*a_2*Z_1^8*X_1^6*Z_2^6*Y_2^2*X_2^6 - 90*a_2*Z_1^6*X_1^8*Z_2^7*X_2^7 - 900*a_2*Z_1^9*X_1^5*Z_2^5*Y_2^2*X_2^7 + 504*a_2*Z_1^7*X_1^7*Z_2^6*X_2^8 + 585*a_2*Z_1^10*X_1^4*Z_2^4*Y_2^2*X_2^8 - 882*a_2*Z_1^8*X_1^6*Z_2^5*X_2^9 - 240*a_2*Z_1^11*X_1^3*Z_2^3*Y_2^2*X_2^9 + 900*a_2*Z_1^9*X_1^5*Z_2^4*X_2^10 + 57*a_2*Z_1^12*X_1^2*Z_2^2*Y_2^2*X_2^10 - 585*a_2*Z_1^10*X_1^4*Z_2^3*X_2^11 - 6*a_2*Z_1^13*X_1*Z_2*Y_2^2*X_2^11 + 240*a_2*Z_1^11*X_1^3*Z_2^2*X_2^12 - 57*a_2*Z_1^12*X_1^2*Z_2*X_2^13 + 6*a_2*Z_1^13*X_1*X_2^14).factor()
# Out:
# X_1 * Z_1^2 * (X_1*Z_2 + 2*Z_1*X_2) * (-X_1*Z_2 + Z_1*X_2)^10 * (a_4^2*Z_2^3 - 3*a_2*a_3*Z_2^2*Y_2 + 3*a_2*a_4*Z_2^2*X_2 - 3*a_1*a_2*Z_2*Y_2*X_2 + 3*a_2^2*Z_2*X_2^2 - 3*a_2*Z_2*Y_2^2 + 3*a_2*X_2^3)

# %%
(Z_1^2*X_1^10*Z_2^12 - 10*Z_1^3*X_1^9*Z_2^11*X_2 + 45*Z_1^4*X_1^8*Z_2^10*X_2^2 - 120*Z_1^5*X_1^7*Z_2^9*X_2^3 + 210*Z_1^6*X_1^6*Z_2^8*X_2^4 - 252*Z_1^7*X_1^5*Z_2^7*X_2^5 + 210*Z_1^8*X_1^4*Z_2^6*X_2^6 - 120*Z_1^9*X_1^3*Z_2^5*X_2^7 + 45*Z_1^10*X_1^2*Z_2^4*X_2^8 - 10*Z_1^11*X_1*Z_2^3*X_2^9 + Z_1^12*Z_2^2*X_2^10).factor()
# Out:
# Z_2^2 * Z_1^2 * (-X_1*Z_2 + Z_1*X_2)^10

# %%
(a_4^2*Z_1^2*X_1^12*Z_2^14 - 3*a_2*a_3*Z_1^2*X_1^12*Z_2^13*Y_2 - 8*a_4^2*Z_1^3*X_1^11*Z_2^13*X_2 + 3*a_2*a_4*Z_1^2*X_1^12*Z_2^13*X_2 + 24*a_2*a_3*Z_1^3*X_1^11*Z_2^12*Y_2*X_2 - 3*a_1*a_2*Z_1^2*X_1^12*Z_2^12*Y_2*X_2 + 25*a_4^2*Z_1^4*X_1^10*Z_2^12*X_2^2 - 24*a_2*a_4*Z_1^3*X_1^11*Z_2^12*X_2^2 + 3*a_2^2*Z_1^2*X_1^12*Z_2^12*X_2^2 - 75*a_2*a_3*Z_1^4*X_1^10*Z_2^11*Y_2*X_2^2 + 24*a_1*a_2*Z_1^3*X_1^11*Z_2^11*Y_2*X_2^2 - 30*a_4^2*Z_1^5*X_1^9*Z_2^11*X_2^3 + 75*a_2*a_4*Z_1^4*X_1^10*Z_2^11*X_2^3 - 24*a_2^2*Z_1^3*X_1^11*Z_2^11*X_2^3 + 90*a_2*a_3*Z_1^5*X_1^9*Z_2^10*Y_2*X_2^3 - 75*a_1*a_2*Z_1^4*X_1^10*Z_2^10*Y_2*X_2^3 - 30*a_4^2*Z_1^6*X_1^8*Z_2^10*X_2^4 - 90*a_2*a_4*Z_1^5*X_1^9*Z_2^10*X_2^4 + 75*a_2^2*Z_1^4*X_1^10*Z_2^10*X_2^4 + 90*a_2*a_3*Z_1^6*X_1^8*Z_2^9*Y_2*X_2^4 + 90*a_1*a_2*Z_1^5*X_1^9*Z_2^9*Y_2*X_2^4 + 168*a_4^2*Z_1^7*X_1^7*Z_2^9*X_2^5 - 90*a_2*a_4*Z_1^6*X_1^8*Z_2^9*X_2^5 - 90*a_2^2*Z_1^5*X_1^9*Z_2^9*X_2^5 - 504*a_2*a_3*Z_1^7*X_1^7*Z_2^8*Y_2*X_2^5 + 90*a_1*a_2*Z_1^6*X_1^8*Z_2^8*Y_2*X_2^5 - 294*a_4^2*Z_1^8*X_1^6*Z_2^8*X_2^6 + 504*a_2*a_4*Z_1^7*X_1^7*Z_2^8*X_2^6 - 90*a_2^2*Z_1^6*X_1^8*Z_2^8*X_2^6 + 882*a_2*a_3*Z_1^8*X_1^6*Z_2^7*Y_2*X_2^6 - 504*a_1*a_2*Z_1^7*X_1^7*Z_2^7*Y_2*X_2^6 + 300*a_4^2*Z_1^9*X_1^5*Z_2^7*X_2^7 - 882*a_2*a_4*Z_1^8*X_1^6*Z_2^7*X_2^7 + 504*a_2^2*Z_1^7*X_1^7*Z_2^7*X_2^7 - 900*a_2*a_3*Z_1^9*X_1^5*Z_2^6*Y_2*X_2^7 + 882*a_1*a_2*Z_1^8*X_1^6*Z_2^6*Y_2*X_2^7 - 195*a_4^2*Z_1^10*X_1^4*Z_2^6*X_2^8 + 900*a_2*a_4*Z_1^9*X_1^5*Z_2^6*X_2^8 - 882*a_2^2*Z_1^8*X_1^6*Z_2^6*X_2^8 + 585*a_2*a_3*Z_1^10*X_1^4*Z_2^5*Y_2*X_2^8 - 900*a_1*a_2*Z_1^9*X_1^5*Z_2^5*Y_2*X_2^8 + 80*a_4^2*Z_1^11*X_1^3*Z_2^5*X_2^9 - 585*a_2*a_4*Z_1^10*X_1^4*Z_2^5*X_2^9 + 900*a_2^2*Z_1^9*X_1^5*Z_2^5*X_2^9 - 240*a_2*a_3*Z_1^11*X_1^3*Z_2^4*Y_2*X_2^9 + 585*a_1*a_2*Z_1^10*X_1^4*Z_2^4*Y_2*X_2^9 - 19*a_4^2*Z_1^12*X_1^2*Z_2^4*X_2^10 + 240*a_2*a_4*Z_1^11*X_1^3*Z_2^4*X_2^10 - 585*a_2^2*Z_1^10*X_1^4*Z_2^4*X_2^10 + 57*a_2*a_3*Z_1^12*X_1^2*Z_2^3*Y_2*X_2^10 - 240*a_1*a_2*Z_1^11*X_1^3*Z_2^3*Y_2*X_2^10 + 2*a_4^2*Z_1^13*X_1*Z_2^3*X_2^11 - 57*a_2*a_4*Z_1^12*X_1^2*Z_2^3*X_2^11 + 240*a_2^2*Z_1^11*X_1^3*Z_2^3*X_2^11 - 6*a_2*a_3*Z_1^13*X_1*Z_2^2*Y_2*X_2^11 + 57*a_1*a_2*Z_1^12*X_1^2*Z_2^2*Y_2*X_2^11 + 6*a_2*a_4*Z_1^13*X_1*Z_2^2*X_2^12 - 57*a_2^2*Z_1^12*X_1^2*Z_2^2*X_2^12 - 6*a_1*a_2*Z_1^13*X_1*Z_2*Y_2*X_2^12 + 6*a_2^2*Z_1^13*X_1*Z_2*X_2^13 - 3*a_2*Z_1^2*X_1^12*Z_2^12*Y_2^2 + 24*a_2*Z_1^3*X_1^11*Z_2^11*Y_2^2*X_2 - 75*a_2*Z_1^4*X_1^10*Z_2^10*Y_2^2*X_2^2 + 3*a_2*Z_1^2*X_1^12*Z_2^11*X_2^3 + 90*a_2*Z_1^5*X_1^9*Z_2^9*Y_2^2*X_2^3 - 24*a_2*Z_1^3*X_1^11*Z_2^10*X_2^4 + 90*a_2*Z_1^6*X_1^8*Z_2^8*Y_2^2*X_2^4 + 75*a_2*Z_1^4*X_1^10*Z_2^9*X_2^5 - 504*a_2*Z_1^7*X_1^7*Z_2^7*Y_2^2*X_2^5 - 90*a_2*Z_1^5*X_1^9*Z_2^8*X_2^6 + 882*a_2*Z_1^8*X_1^6*Z_2^6*Y_2^2*X_2^6 - 90*a_2*Z_1^6*X_1^8*Z_2^7*X_2^7 - 900*a_2*Z_1^9*X_1^5*Z_2^5*Y_2^2*X_2^7 + 504*a_2*Z_1^7*X_1^7*Z_2^6*X_2^8 + 585*a_2*Z_1^10*X_1^4*Z_2^4*Y_2^2*X_2^8 - 882*a_2*Z_1^8*X_1^6*Z_2^5*X_2^9 - 240*a_2*Z_1^11*X_1^3*Z_2^3*Y_2^2*X_2^9 + 900*a_2*Z_1^9*X_1^5*Z_2^4*X_2^10 + 57*a_2*Z_1^12*X_1^2*Z_2^2*Y_2^2*X_2^10 - 585*a_2*Z_1^10*X_1^4*Z_2^3*X_2^11 - 6*a_2*Z_1^13*X_1*Z_2*Y_2^2*X_2^11 + 240*a_2*Z_1^11*X_1^3*Z_2^2*X_2^12 - 57*a_2*Z_1^12*X_1^2*Z_2*X_2^13 + 6*a_2*Z_1^13*X_1*X_2^14)/ (Z_1^2*X_1^10*Z_2^12 - 10*Z_1^3*X_1^9*Z_2^11*X_2 + 45*Z_1^4*X_1^8*Z_2^10*X_2^2 - 120*Z_1^5*X_1^7*Z_2^9*X_2^3 + 210*Z_1^6*X_1^6*Z_2^8*X_2^4 - 252*Z_1^7*X_1^5*Z_2^7*X_2^5 + 210*Z_1^8*X_1^4*Z_2^6*X_2^6 - 120*Z_1^9*X_1^3*Z_2^5*X_2^7 + 45*Z_1^10*X_1^2*Z_2^4*X_2^8 - 10*Z_1^11*X_1*Z_2^3*X_2^9 + Z_1^12*Z_2^2*X_2^10)
# Out:
# (a_4^2*X_1^2*Z_2^4 - 3*a_2*a_3*X_1^2*Z_2^3*Y_2 + 2*a_4^2*Z_1*X_1*Z_2^3*X_2 + 3*a_2*a_4*X_1^2*Z_2^3*X_2 - 6*a_2*a_3*Z_1*X_1*Z_2^2*Y_2*X_2 - 3*a_1*a_2*X_1^2*Z_2^2*Y_2*X_2 + 6*a_2*a_4*Z_1*X_1*Z_2^2*X_2^2 + 3*a_2^2*X_1^2*Z_2^2*X_2^2 - 6*a_1*a_2*Z_1*X_1*Z_2*Y_2*X_2^2 + 6*a_2^2*Z_1*X_1*Z_2*X_2^3 - 3*a_2*X_1^2*Z_2^2*Y_2^2 - 6*a_2*Z_1*X_1*Z_2*Y_2^2*X_2 + 3*a_2*X_1^2*Z_2*X_2^3 + 6*a_2*Z_1*X_1*X_2^4)/Z_2^2

# %%
_.factor()
# Out:
# Z_2^-2 * X_1 * (X_1*Z_2 + 2*Z_1*X_2) * (a_4^2*Z_2^3 - 3*a_2*a_3*Z_2^2*Y_2 + 3*a_2*a_4*Z_2^2*X_2 - 3*a_1*a_2*Z_2*Y_2*X_2 + 3*a_2^2*Z_2*X_2^2 - 3*a_2*Z_2*Y_2^2 + 3*a_2*X_2^3)

# %%
(- 3*a_2*a_3*Z_2^2*Y_2 + 3*a_2*a_4*Z_2^2*X_2 - 3*a_1*a_2*Z_2*Y_2*X_2 + 3*a_2^2*Z_2*X_2^2 - 3*a_2*Z_2*Y_2^2 + 3*a_2*X_2^3).factor()
# Out:
# (3) * a_2 * (-a_3*Z_2^2*Y_2 + a_4*Z_2^2*X_2 - a_1*Z_2*Y_2*X_2 + a_2*Z_2*X_2^2 - Z_2*Y_2^2 + X_2^3)

# %%
(a_4^2*Z_1^2*X_1^12*Z_2^14 - 3*a_2*a_3*Z_1^2*X_1^12*Z_2^13*Y_2 - 9*a_4^2*Z_1^3*X_1^11*Z_2^13*X_2 + 3*a_2*a_4*Z_1^2*X_1^12*Z_2^13*X_2 + 27*a_2*a_3*Z_1^3*X_1^11*Z_2^12*Y_2*X_2 - 3*a_1*a_2*Z_1^2*X_1^12*Z_2^12*Y_2*X_2 + 34*a_4^2*Z_1^4*X_1^10*Z_2^12*X_2^2 - 27*a_2*a_4*Z_1^3*X_1^11*Z_2^12*X_2^2 + 3*a_2^2*Z_1^2*X_1^12*Z_2^12*X_2^2 - 102*a_2*a_3*Z_1^4*X_1^10*Z_2^11*Y_2*X_2^2 + 27*a_1*a_2*Z_1^3*X_1^11*Z_2^11*Y_2*X_2^2 - 65*a_4^2*Z_1^5*X_1^9*Z_2^11*X_2^3 + 102*a_2*a_4*Z_1^4*X_1^10*Z_2^11*X_2^3 - 27*a_2^2*Z_1^3*X_1^11*Z_2^11*X_2^3 + 195*a_2*a_3*Z_1^5*X_1^9*Z_2^10*Y_2*X_2^3 - 102*a_1*a_2*Z_1^4*X_1^10*Z_2^10*Y_2*X_2^3 + 45*a_4^2*Z_1^6*X_1^8*Z_2^10*X_2^4 - 195*a_2*a_4*Z_1^5*X_1^9*Z_2^10*X_2^4 + 102*a_2^2*Z_1^4*X_1^10*Z_2^10*X_2^4 - 135*a_2*a_3*Z_1^6*X_1^8*Z_2^9*Y_2*X_2^4 + 195*a_1*a_2*Z_1^5*X_1^9*Z_2^9*Y_2*X_2^4 + 78*a_4^2*Z_1^7*X_1^7*Z_2^9*X_2^5 + 135*a_2*a_4*Z_1^6*X_1^8*Z_2^9*X_2^5 - 195*a_2^2*Z_1^5*X_1^9*Z_2^9*X_2^5 - 234*a_2*a_3*Z_1^7*X_1^7*Z_2^8*Y_2*X_2^5 - 135*a_1*a_2*Z_1^6*X_1^8*Z_2^8*Y_2*X_2^5 - 252*a_4^2*Z_1^8*X_1^6*Z_2^8*X_2^6 + 234*a_2*a_4*Z_1^7*X_1^7*Z_2^8*X_2^6 + 135*a_2^2*Z_1^6*X_1^8*Z_2^8*X_2^6 + 756*a_2*a_3*Z_1^8*X_1^6*Z_2^7*Y_2*X_2^6 - 234*a_1*a_2*Z_1^7*X_1^7*Z_2^7*Y_2*X_2^6 + 342*a_4^2*Z_1^9*X_1^5*Z_2^7*X_2^7 - 756*a_2*a_4*Z_1^8*X_1^6*Z_2^7*X_2^7 + 234*a_2^2*Z_1^7*X_1^7*Z_2^7*X_2^7 - 1026*a_2*a_3*Z_1^9*X_1^5*Z_2^6*Y_2*X_2^7 + 756*a_1*a_2*Z_1^8*X_1^6*Z_2^6*Y_2*X_2^7 - 285*a_4^2*Z_1^10*X_1^4*Z_2^6*X_2^8 + 1026*a_2*a_4*Z_1^9*X_1^5*Z_2^6*X_2^8 - 756*a_2^2*Z_1^8*X_1^6*Z_2^6*X_2^8 + 855*a_2*a_3*Z_1^10*X_1^4*Z_2^5*Y_2*X_2^8 - 1026*a_1*a_2*Z_1^9*X_1^5*Z_2^5*Y_2*X_2^8 + 155*a_4^2*Z_1^11*X_1^3*Z_2^5*X_2^9 - 855*a_2*a_4*Z_1^10*X_1^4*Z_2^5*X_2^9 + 1026*a_2^2*Z_1^9*X_1^5*Z_2^5*X_2^9 - 465*a_2*a_3*Z_1^11*X_1^3*Z_2^4*Y_2*X_2^9 + 855*a_1*a_2*Z_1^10*X_1^4*Z_2^4*Y_2*X_2^9 - 54*a_4^2*Z_1^12*X_1^2*Z_2^4*X_2^10 + 465*a_2*a_4*Z_1^11*X_1^3*Z_2^4*X_2^10 - 855*a_2^2*Z_1^10*X_1^4*Z_2^4*X_2^10 + 162*a_2*a_3*Z_1^12*X_1^2*Z_2^3*Y_2*X_2^10 - 465*a_1*a_2*Z_1^11*X_1^3*Z_2^3*Y_2*X_2^10 + 11*a_4^2*Z_1^13*X_1*Z_2^3*X_2^11 - 162*a_2*a_4*Z_1^12*X_1^2*Z_2^3*X_2^11 + 465*a_2^2*Z_1^11*X_1^3*Z_2^3*X_2^11 - 33*a_2*a_3*Z_1^13*X_1*Z_2^2*Y_2*X_2^11 + 162*a_1*a_2*Z_1^12*X_1^2*Z_2^2*Y_2*X_2^11 - a_4^2*Z_1^14*Z_2^2*X_2^12 + 3*a_2*a_3*Z_1^13*Y_1*Z_2^2*X_2^12 + 30*a_2*a_4*Z_1^13*X_1*Z_2^2*X_2^12 + 3*a_1*a_2*Z_1^12*Y_1*X_1*Z_2^2*X_2^12 - 165*a_2^2*Z_1^12*X_1^2*Z_2^2*X_2^12 - 33*a_1*a_2*Z_1^13*X_1*Z_2*Y_2*X_2^12 + 33*a_2^2*Z_1^13*X_1*Z_2*X_2^13 - 3*a_2*Z_1^2*X_1^12*Z_2^12*Y_2^2 + 27*a_2*Z_1^3*X_1^11*Z_2^11*Y_2^2*X_2 - 102*a_2*Z_1^4*X_1^10*Z_2^10*Y_2^2*X_2^2 + 3*a_2*Z_1^2*X_1^12*Z_2^11*X_2^3 + 195*a_2*Z_1^5*X_1^9*Z_2^9*Y_2^2*X_2^3 - 27*a_2*Z_1^3*X_1^11*Z_2^10*X_2^4 - 135*a_2*Z_1^6*X_1^8*Z_2^8*Y_2^2*X_2^4 + 102*a_2*Z_1^4*X_1^10*Z_2^9*X_2^5 - 234*a_2*Z_1^7*X_1^7*Z_2^7*Y_2^2*X_2^5 - 195*a_2*Z_1^5*X_1^9*Z_2^8*X_2^6 + 756*a_2*Z_1^8*X_1^6*Z_2^6*Y_2^2*X_2^6 + 135*a_2*Z_1^6*X_1^8*Z_2^7*X_2^7 - 1026*a_2*Z_1^9*X_1^5*Z_2^5*Y_2^2*X_2^7 + 234*a_2*Z_1^7*X_1^7*Z_2^6*X_2^8 + 855*a_2*Z_1^10*X_1^4*Z_2^4*Y_2^2*X_2^8 - 756*a_2*Z_1^8*X_1^6*Z_2^5*X_2^9 - 465*a_2*Z_1^11*X_1^3*Z_2^3*Y_2^2*X_2^9 + 1026*a_2*Z_1^9*X_1^5*Z_2^4*X_2^10 + 162*a_2*Z_1^12*X_1^2*Z_2^2*Y_2^2*X_2^10 - 855*a_2*Z_1^10*X_1^4*Z_2^3*X_2^11 - 33*a_2*Z_1^13*X_1*Z_2*Y_2^2*X_2^11 + 3*a_2*Z_1^12*Y_1^2*Z_2^2*X_2^12 + 462*a_2*Z_1^11*X_1^3*Z_2^2*X_2^12 - 162*a_2*Z_1^12*X_1^2*Z_2*X_2^13 + 33*a_2*Z_1^13*X_1*X_2^14)/(Z_1^2*X_1^10*Z_2^12 - 10*Z_1^3*X_1^9*Z_2^11*X_2 + 45*Z_1^4*X_1^8*Z_2^10*X_2^2 - 120*Z_1^5*X_1^7*Z_2^9*X_2^3 + 210*Z_1^6*X_1^6*Z_2^8*X_2^4 - 252*Z_1^7*X_1^5*Z_2^7*X_2^5 + 210*Z_1^8*X_1^4*Z_2^6*X_2^6 - 120*Z_1^9*X_1^3*Z_2^5*X_2^7 + 45*Z_1^10*X_1^2*Z_2^4*X_2^8 - 10*Z_1^11*X_1*Z_2^3*X_2^9 + Z_1^12*Z_2^2*X_2^10)
# Out:
# (a_4^2*X_1^12*Z_2^14 - 3*a_2*a_3*X_1^12*Z_2^13*Y_2 - 9*a_4^2*Z_1*X_1^11*Z_2^13*X_2 + 3*a_2*a_4*X_1^12*Z_2^13*X_2 + 27*a_2*a_3*Z_1*X_1^11*Z_2^12*Y_2*X_2 - 3*a_1*a_2*X_1^12*Z_2^12*Y_2*X_2 + 34*a_4^2*Z_1^2*X_1^10*Z_2^12*X_2^2 - 27*a_2*a_4*Z_1*X_1^11*Z_2^12*X_2^2 + 3*a_2^2*X_1^12*Z_2^12*X_2^2 - 102*a_2*a_3*Z_1^2*X_1^10*Z_2^11*Y_2*X_2^2 + 27*a_1*a_2*Z_1*X_1^11*Z_2^11*Y_2*X_2^2 - 65*a_4^2*Z_1^3*X_1^9*Z_2^11*X_2^3 + 102*a_2*a_4*Z_1^2*X_1^10*Z_2^11*X_2^3 - 27*a_2^2*Z_1*X_1^11*Z_2^11*X_2^3 + 195*a_2*a_3*Z_1^3*X_1^9*Z_2^10*Y_2*X_2^3 - 102*a_1*a_2*Z_1^2*X_1^10*Z_2^10*Y_2*X_2^3 + 45*a_4^2*Z_1^4*X_1^8*Z_2^10*X_2^4 - 195*a_2*a_4*Z_1^3*X_1^9*Z_2^10*X_2^4 + 102*a_2^2*Z_1^2*X_1^10*Z_2^10*X_2^4 - 135*a_2*a_3*Z_1^4*X_1^8*Z_2^9*Y_2*X_2^4 + 195*a_1*a_2*Z_1^3*X_1^9*Z_2^9*Y_2*X_2^4 + 78*a_4^2*Z_1^5*X_1^7*Z_2^9*X_2^5 + 135*a_2*a_4*Z_1^4*X_1^8*Z_2^9*X_2^5 - 195*a_2^2*Z_1^3*X_1^9*Z_2^9*X_2^5 - 234*a_2*a_3*Z_1^5*X_1^7*Z_2^8*Y_2*X_2^5 - 135*a_1*a_2*Z_1^4*X_1^8*Z_2^8*Y_2*X_2^5 - 252*a_4^2*Z_1^6*X_1^6*Z_2^8*X_2^6
# ...

# %%
_.factor()
# Out:
# Z_2^-2 * (-X_1*Z_2 + Z_1*X_2)^-10 * (a_4^2*X_1^12*Z_2^14 - 3*a_2*a_3*X_1^12*Z_2^13*Y_2 - 9*a_4^2*Z_1*X_1^11*Z_2^13*X_2 + 3*a_2*a_4*X_1^12*Z_2^13*X_2 + 27*a_2*a_3*Z_1*X_1^11*Z_2^12*Y_2*X_2 - 3*a_1*a_2*X_1^12*Z_2^12*Y_2*X_2 + 34*a_4^2*Z_1^2*X_1^10*Z_2^12*X_2^2 - 27*a_2*a_4*Z_1*X_1^11*Z_2^12*X_2^2 + 3*a_2^2*X_1^12*Z_2^12*X_2^2 - 102*a_2*a_3*Z_1^2*X_1^10*Z_2^11*Y_2*X_2^2 + 27*a_1*a_2*Z_1*X_1^11*Z_2^11*Y_2*X_2^2 - 65*a_4^2*Z_1^3*X_1^9*Z_2^11*X_2^3 + 102*a_2*a_4*Z_1^2*X_1^10*Z_2^11*X_2^3 - 27*a_2^2*Z_1*X_1^11*Z_2^11*X_2^3 + 195*a_2*a_3*Z_1^3*X_1^9*Z_2^10*Y_2*X_2^3 - 102*a_1*a_2*Z_1^2*X_1^10*Z_2^10*Y_2*X_2^3 + 45*a_4^2*Z_1^4*X_1^8*Z_2^10*X_2^4 - 195*a_2*a_4*Z_1^3*X_1^9*Z_2^10*X_2^4 + 102*a_2^2*Z_1^2*X_1^10*Z_2^10*X_2^4 - 135*a_2*a_3*Z_1^4*X_1^8*Z_2^9*Y_2*X_2^4 + 195*a_1*a_2*Z_1^3*X_1^9*Z_2^9*Y_2*X_2^4 + 78*a_4^2*Z_1^5*X_1^7*Z_2^9*X_2^5 + 135*a_2*a_4*Z_1^4*X_1^8*Z_2^9*X_2^5 - 195*a_2^2*Z_1^3*X_1^9*Z_2^9*X_2^5 - 234*a_2*a_3*Z_1^5*X_1^7*Z_2^8*Y_2*X_2^5 - 135*a_1*a_2*Z_1^4*X_1^8*Z_2^8*Y_2*X_2^5
# ...

# %%
(-(x_1*z_2+x_2*z_1)*(x_1*z_2-x_2*z_1) + (x_1*z_2+2*x_2*z_1)*(x_1*z_2)).factor()
# Out:
# X_2 * Z_1 * (2*X_1*Z_2 + Z_1*X_2)

# %%
z_32 = z_31 * syz
z_32
# Out:
# (-a_3bar^3*Z_1bar^3*X_1bar^5*Z_2bar^8 - 2*a_1bar*a_3bar^2*Z_1bar^2*X_1bar^6*Z_2bar^8 - a_1bar^2*a_3bar*Z_1bar*X_1bar^7*Z_2bar^8 + 5*a_3bar^3*Z_1bar^4*X_1bar^4*Z_2bar^7*X_2bar + 9*a_1bar*a_3bar^2*Z_1bar^3*X_1bar^5*Z_2bar^7*X_2bar + 3*a_1bar^2*a_3bar*Z_1bar^2*X_1bar^6*Z_2bar^7*X_2bar - a_1bar^3*Z_1bar*X_1bar^7*Z_2bar^7*X_2bar - 10*a_3bar^3*Z_1bar^5*X_1bar^3*Z_2bar^6*X_2bar^2 - 15*a_1bar*a_3bar^2*Z_1bar^4*X_1bar^4*Z_2bar^6*X_2bar^2 + 5*a_1bar^3*Z_1bar^2*X_1bar^6*Z_2bar^6*X_2bar^2 + 10*a_3bar^3*Z_1bar^6*X_1bar^2*Z_2bar^5*X_2bar^3 + 10*a_1bar*a_3bar^2*Z_1bar^5*X_1bar^3*Z_2bar^5*X_2bar^3 - 10*a_1bar^2*a_3bar*Z_1bar^4*X_1bar^4*Z_2bar^5*X_2bar^3 - 10*a_1bar^3*Z_1bar^3*X_1bar^5*Z_2bar^5*X_2bar^3 - 5*a_3bar^3*Z_1bar^7*X_1bar*Z_2bar^4*X_2bar^4 + 15*a_1bar^2*a_3bar*Z_1bar^5*X_1bar^3*Z_2bar^4*X_2bar^4 + 10*a_1bar^3*Z_1bar^4*X_1bar^4*Z_2bar^4*X_2bar^4 + a_3bar^3*Z_1bar^8*Z_2bar^3*X_2bar^5 - 3*a_1bar*a_3bar^2*Z_1bar^7*X_1bar*Z_2bar^3*X_2bar^5 - 9*a_1bar^2*a_3bar*Z_1bar^6*X_1bar^2*Z_2bar^3*X_2bar^5 
# ...

# %%
z_32 + (3*x_1*x_2*(x_1*y_2+x_2*y_1)+y_1*y_2*(y_1*z_2+y_2*z_1)+3*a_1*x_1^2*x_2^2\
            +a_1*(2*x_1*y_2+y_1*x_2)*y_1*z_2+a_1^2*x_1*z_2*(2*x_2*y_1+x_1*y_2)\
            +a_2*x_1*x_2*(y_1*z_2+y_2*z_1)\
            +a_2*(x_1*y_2+x_2*y_1)*(x_1*z_2+x_2*z_1)\
            +a_1^3*x_1^2*x_2*z_2+a_1*a_2*x_1*x_2*(2*x_1*z_2+x_2*z_1)\
            +3*a_3*x_1*x_2^2*z_1+a_3*y_1*z_2*(y_1*z_2+2*y_2*z_1)\
            +2*a_1*a_3*x_1*z_2*(y_1*z_2+y_2*z_1)\
            +2*a_1*a_3*x_2*y_1*z_1*z_2+a_4*(x_1*y_2+x_2*y_1)*z_1*z_2\
            +a_4*(x_1*z_2+x_2*z_1)*(y_1*z_2+y_2*z_1)\
            +(a_1^2*a_3+a_1*a_4)*x_1*z_2*(x_1*z_2+2*x_2*z_1)+a_2*a_3*x_2*z_1*(2*x_1*z_2+x_2*z_1)\
            +a_3^2*y_1*z_1*z_2^2+(a_3^2+3*a_6)*(y_1*z_2+y_2*z_1)*z_1*z_2\
            +a_1*a_3^2*(2*x_1*z_2+x_2*z_1)*z_1*z_2+3*a_1*a_6*x_1*z_1*z_2^2\
            +a_3*a_4*(x_1*z_2+2*x_2*z_1)*z_1*z_2+(a_3^3+3*a_3*a_6)*z_1^2*z_2^2)
# Out:
# 0

# %%
x_33 = x_31 * sxz
x_33
# Out:
# (-a_2bar*a_3bar^2*Z_1bar^3*X_1bar^7*Z_2bar^10 + a_1bar*a_3bar*a_4bar*Z_1bar^3*X_1bar^7*Z_2bar^10 - a_1bar^2*a_3bar*Z_1bar^3*X_1bar^7*Z_2bar^9*Y_2bar + 7*a_2bar*a_3bar^2*Z_1bar^4*X_1bar^6*Z_2bar^9*X_2bar - 7*a_1bar*a_3bar*a_4bar*Z_1bar^4*X_1bar^6*Z_2bar^9*X_2bar + a_1bar^2*a_4bar*Z_1bar^3*X_1bar^7*Z_2bar^9*X_2bar + 7*a_1bar^2*a_3bar*Z_1bar^4*X_1bar^6*Z_2bar^8*Y_2bar*X_2bar - a_1bar^3*Z_1bar^3*X_1bar^7*Z_2bar^8*Y_2bar*X_2bar - 21*a_2bar*a_3bar^2*Z_1bar^5*X_1bar^5*Z_2bar^8*X_2bar^2 + 21*a_1bar*a_3bar*a_4bar*Z_1bar^5*X_1bar^5*Z_2bar^8*X_2bar^2 - 7*a_1bar^2*a_4bar*Z_1bar^4*X_1bar^6*Z_2bar^8*X_2bar^2 + a_1bar^2*a_2bar*Z_1bar^3*X_1bar^7*Z_2bar^8*X_2bar^2 - 21*a_1bar^2*a_3bar*Z_1bar^5*X_1bar^5*Z_2bar^7*Y_2bar*X_2bar^2 + 7*a_1bar^3*Z_1bar^4*X_1bar^6*Z_2bar^7*Y_2bar*X_2bar^2 + 35*a_2bar*a_3bar^2*Z_1bar^6*X_1bar^4*Z_2bar^7*X_2bar^3 - 35*a_1bar*a_3bar*a_4bar*Z_1bar^6*X_1bar^4*Z_2bar^7*X_2bar^3 + 21*a_1bar^2*a_4bar*Z_1bar^5*X_1bar^5*Z_2bar^7*X_2bar^3 - 7*a_1bar^2*a_2bar*Z_1bar^4*X_1bar^6*Z_2bar^7
# ...

# %%
x_33 + ((x_1*y_2+x_2*y_1)*(x_1*y_2-x_2*y_1)+a_1*x_1*x_2*(x_1*y_2-x_2*y_1)\
            -a_3*x_1*x_2*(y_1*z_2-y_2*z_1)+a_3*(x_1*y_2+x_2*y_1)*(x_1*z_2-x_2*z_1)\
            +(a_1*a_3+a_4)*x_1*x_2*(x_1*z_2-x_2*z_1)\
            +(a_3^2+3*a_6)*(x_1*z_2+x_2*z_1)*(x_1*z_2-x_2*z_1)\
            +(a_1^2*a_6-a_1*a_3*a_4+a_2*a_3^2+4*a_2*a_6-a_4^2)*(x_1*z_2-x_2*z_1)*z_1*z_2)
# Out:
# 0

# %%
y_33 = y_31 * sxz
y_33
# Out:
# (a_1bar*a_2bar*a_3bar^2*Z_1bar^3*X_1bar^9*Z_2bar^12 - a_1bar^2*a_3bar*a_4bar*Z_1bar^3*X_1bar^9*Z_2bar^12 + a_1bar^3*a_3bar*Z_1bar^3*X_1bar^9*Z_2bar^11*Y_2bar - 9*a_1bar*a_2bar*a_3bar^2*Z_1bar^4*X_1bar^8*Z_2bar^11*X_2bar + 9*a_1bar^2*a_3bar*a_4bar*Z_1bar^4*X_1bar^8*Z_2bar^11*X_2bar - a_1bar^3*a_4bar*Z_1bar^3*X_1bar^9*Z_2bar^11*X_2bar - 9*a_1bar^3*a_3bar*Z_1bar^4*X_1bar^8*Z_2bar^10*Y_2bar*X_2bar + a_1bar^4*Z_1bar^3*X_1bar^9*Z_2bar^10*Y_2bar*X_2bar + 36*a_1bar*a_2bar*a_3bar^2*Z_1bar^5*X_1bar^7*Z_2bar^10*X_2bar^2 - 36*a_1bar^2*a_3bar*a_4bar*Z_1bar^5*X_1bar^7*Z_2bar^10*X_2bar^2 + 9*a_1bar^3*a_4bar*Z_1bar^4*X_1bar^8*Z_2bar^10*X_2bar^2 - a_1bar^3*a_2bar*Z_1bar^3*X_1bar^9*Z_2bar^10*X_2bar^2 + 36*a_1bar^3*a_3bar*Z_1bar^5*X_1bar^7*Z_2bar^9*Y_2bar*X_2bar^2 - 9*a_1bar^4*Z_1bar^4*X_1bar^8*Z_2bar^9*Y_2bar*X_2bar^2 - 84*a_1bar*a_2bar*a_3bar^2*Z_1bar^6*X_1bar^6*Z_2bar^9*X_2bar^3 + 84*a_1bar^2*a_3bar*a_4bar*Z_1bar^6*X_1bar^6*Z_2bar^9*X_2bar^3 - 36*a_1bar^3*a_4bar*Z_1bar^5*X_1bar^7*Z_2bar^9*X_2bar^3 +
# ...

# %%
y_33 + ( (x_1*y_2-x_2*y_1)*y_1*y_2+a_2*x_1*x_2*(x_1*y_2-x_2*y_1)\
            +2*a_3*(x_1*z_2-x_2*z_1)*y_1*y_2\
            -(a_1*a_3+3*a_4)*x_1*x_2*(y_1*z_2-y_2*z_1)\
            +(a_1*a_3+a_4)*(x_1*y_2+x_2*y_1)*(x_1*z_2-x_2*z_1)\
            -(a_1*a_4-a_2*a_3)*x_1*x_2*(x_1*z_2-x_2*z_1)\
            +(2*a_3^2+3*a_6)*(x_1*y_2-x_2*y_1)*z_1*z_2\
            -3*a_6*(x_1*z_2+x_2*z_1)*(y_1*z_2-y_2*z_1)\
            -(3*a_1*a_6-a_3*a_4)*(x_1*z_2+x_2*z_1)*(x_1*z_2-x_2*z_1)\
            -(a_1^2*a_6-a_1*a_3*a_4+a_2*a_3^2+4*a_2*a_6-a_4^2)*(y_1*z_2-y_2*z_1)*z_1*z_2\
            -(a_1^3*a_6-a_1^2*a_3*a_4+a_1*a_2*a_3^2+4*a_1*a_2*a_6\
            -a_1*a_4^2-a_3^3-3*a_3*a_6)*(x_1*z_2-x_2*z_1)*z_1*z_2)
# Out:
# 0

# %%
z_33 = z_31 * sxz
z_33
# Out:
# (a_3bar^2*Z_1bar^2*X_1bar^4*Z_2bar^6 + a_1bar*a_3bar*Z_1bar*X_1bar^5*Z_2bar^6 - 4*a_3bar^2*Z_1bar^3*X_1bar^3*Z_2bar^5*X_2bar - 3*a_1bar*a_3bar*Z_1bar^2*X_1bar^4*Z_2bar^5*X_2bar + a_1bar^2*Z_1bar*X_1bar^5*Z_2bar^5*X_2bar + 6*a_3bar^2*Z_1bar^4*X_1bar^2*Z_2bar^4*X_2bar^2 + 2*a_1bar*a_3bar*Z_1bar^3*X_1bar^3*Z_2bar^4*X_2bar^2 - 4*a_1bar^2*Z_1bar^2*X_1bar^4*Z_2bar^4*X_2bar^2 - 4*a_3bar^2*Z_1bar^5*X_1bar*Z_2bar^3*X_2bar^3 + 2*a_1bar*a_3bar*Z_1bar^4*X_1bar^2*Z_2bar^3*X_2bar^3 + 6*a_1bar^2*Z_1bar^3*X_1bar^3*Z_2bar^3*X_2bar^3 + a_3bar^2*Z_1bar^6*Z_2bar^2*X_2bar^4 - 3*a_1bar*a_3bar*Z_1bar^5*X_1bar*Z_2bar^2*X_2bar^4 - 4*a_1bar^2*Z_1bar^4*X_1bar^2*Z_2bar^2*X_2bar^4 + a_1bar*a_3bar*Z_1bar^6*Z_2bar*X_2bar^5 + a_1bar^2*Z_1bar^5*X_1bar*Z_2bar*X_2bar^5 + a_3bar*Z_1bar*Y_1bar*X_1bar^4*Z_2bar^6 + a_4bar*Z_1bar*X_1bar^5*Z_2bar^6 + 3*a_3bar*Z_1bar^2*X_1bar^4*Z_2bar^5*Y_2bar + a_1bar*Z_1bar*X_1bar^5*Z_2bar^5*Y_2bar - 9*a_4bar*Z_1bar^2*X_1bar^4*Z_2bar^5*X_2bar + 5*a_1bar*Z_1bar*Y_1bar*X_1bar^4*Z_2bar^5*X_2b
# ...

# %%
z_33 + (-(x_1*y_2+x_2*y_1)*(y_1*z_2-y_2*z_1)-(x_1*z_2-x_2*z_1)*y_1*y_2\
            -a_1*x_1*x_2*(y_1*z_2-y_2*z_1)-a_1*(x_1*y_2+x_2*y_1)*(x_1*z_2-x_2*z_1)\
            -(a_1^2+a_2)*x_1*x_2*(x_1*z_2-x_2*z_1)-a_3*(x_1*y_2-x_2*y_1)*z_1*z_2\
            -a_3*(x_1*z_2+x_2*z_1)*(y_1*z_2-y_2*z_1)\
            -(a_1*a_3+a_4)*(x_1*z_2+x_2*z_1)*(x_1*z_2-x_2*z_1)\
            -(a_3^2+3*a_6)*(x_1*z_2-x_2*z_1)*z_1*z_2)
# Out:
# 0
