# %%
E = EllipticCurve("91a1")
p = 103
N= 4000

# %%
Ep = E.change_ring(GF(p))

# %%
alpha,beta=zip(*Ep.frobenius_polynomial().roots(CC))[0]

# %%
l = [RR((alpha^n + beta^n)/(2*sqrt(p^n))) for n in range(1,N)]
histogram(l,bins=30)
# Out:
# Graphics object consisting of 1 graphics primitive
